# %% [markdown]
# # Gen AI

# %% [markdown]
# ## Intro

# %% [markdown]
# - GenAI is a type of AI that creates new content such as text, images, music, videos or code by learning patterns from existing data, mimicking human creativity
#
# - In ML, we mostly create 2 type of models like Regression and Classification but it was never used for tasks where **human creativity** is required until **GenAI** which can CREATE new content like code, texts, images videos etc
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Impact areas

# %% [markdown]
# 1. **Customer Support**: With the increase of buisnesses and population, complaints also increased so now companies like zomato swiggy uber amazon etc they have AI chatbots as 1st layer of customer supports who try to resolve basic issues which resolved the high number of complaints to very few which remain unresolved for actual human support -- Buisnesses now saving money on human resources and also delivering efficient responses to their customers
#
# 2. **Content Creation**: content creation is the forte of GenAI so it has penetrated this domain a lot, now blogs, websites, videos, music, images are being generated using GenAI tools.
#
# 3. **Education**: GenAI tools have evolved education system completly, now most of our queries are being resolved quickly and efficiently using chatgpt
#
# 4. **Software development**: GenAI tools can write production grade codes very efficiently which has evolved software development field, now we can just give prompts and it will write codes of a project completly.

# %% [markdown]
# ## Is GenAI Successfull?

# %% [markdown]
# 1. Does it solve real world problems?
# - Yes like customer support being hanled at scale
#
# 2. Is it usefull on daily basis?
# - Yes, We use chatgpt daily
#
# 3. Is it impacting world economics?
# - Yes, With new AI models being announced, economies do change like deepseek, claude created a lot of buss in world economies
#
# 4. Is it creating new jobs?
# - Yes, GenAI Engineer, AI Engineer, Prompt Engineer etc
#
# 5. Is it accessible?
# - Yes, very much, only requires user to know english.

# %% [markdown]
# ## Mental Model

# %% [markdown]
# - **Foundation model like LLMs** which can perform multiple tasks like text generation, prediciton, code creation, image creation, sentiment analysis etc bcoz they were trained on huge amount of data and have billions of parameters
#
# - We can either USE foundation model or CREATE foundation model means we can have a user perspective or a creator perspective.
#
# - Builder Perspective:
#     - Should know ML/DL/Tensorflow or Pytorch
#     - Should know Transformer architecture
#     - Types of transformers
#     - Pretraining
#     - Optimizations
#     - Fine tuning
#     - Evaluation
#     - Deployment
#
# - User Perspective:
#     - Building basic LLM apps
#     - Open source vs Closed source apps
#     - Using LLMs APIs
#     - Langchain, Hugging face, Ollama
#     - **Prompt Engineering**
#     - **RAGs**
#     - Fine Tuning
#     - AI Agents
#     - LLMOps
#     - Miscellaneous

# %% [markdown]
# ## Do we need to learn both?

# %% [markdown]
# 1. builder side is for researcher/data scientists etc
# 2. user side is for software developers who can integrate LLM in thier apps
#
# - AI Engineer should have idea about how bulder side operates and can also create AI apps.
# - Learn below:
#     1. Transformer architecture in deep learning
#     2. Pytorch
#     3. Types of transformers etc
# - Cover both side parallely

# %% [markdown]
# # Langchain

# %% [markdown]
# - Langchain is an open source framework to build llm apps such as chatbots, question ansewring systems, RAGs, AI agents etc
# - Langchain suports all major LLM
# - Simplifies developing llm apps
# - All major services integration like  database, cloud etc
# - Its open source
# - Supports major types of GenAI apps
# - With langchain we get a flavour of various curriculum of user side module

# %% [markdown]
# ## Curriculum

# %% [markdown]
# 1. Fundamentals
# 2. RAG based appllications
# 3. AI Agents

# %% [markdown]
# ## Fundamentals

# %% [markdown]
# - Langchain is an open source framework to build llm apps
#
# - **Why do we need langchain?**
# - LLM app building requires a lot of different components like embedding models, llm models, cloud servers, database etc
# - Lamgchain framework is designed in such a way that we dont have to worry about orchestration, embedding models, llm models, cloud servers, database etc bcoz it provides seamless integration ith all major service providers like AWS, GCP, Azure, Postgres, SQL etc also it has built in fatures like **Chain** which makes orchestration very easy.

# %% [markdown]
# ## Core Components

# %% [markdown]
# ### Components

# %% [markdown]
# 1. **Models**: Used to interact with AI models, We dont have to write different types of codes to interact with different LLM apis. This standardizes the use of code and with very minimal change we can switch between LLMs
#
# ```python
# # OpenAI Model
# from langchain_openai import ChatOpenAI
#
# openai_llm = ChatOpenAI(model="gpt-4o", temperature=0)
#
# openai_response = openai_llm.invoke(
#     "Explain LangChain in one sentence."
# )
#
# print("OpenAI Response:")
# print(openai_response.content)
#
#
# # Anthropic Model
# from langchain_anthropic import ChatAnthropic
#
# anthropic_llm = ChatAnthropic(
#     model="claude-3-5-sonnet-20240620"
# )
#
# anthropic_response = anthropic_llm.invoke(
#     "What is a prompt template?"
# )
#
# print("\nAnthropic Response:")
# print(anthropic_response.content)
# ```
#
# - We can interact with 2 types of models:
#     1. Language models: Text input Text output
#     2. Embedding models: Text input Vector output
#
# 2. **Prompts:** Text input provided to the LLMs, LLMs output is very sensitive and output changes very quickly with slight change in the prompt.
#
# 3. **Chains:** We can build pipelines in langchain using **Chains**, output of 1 stage becomes input for next stage automatically.
#
# 4. **Indexes:** Indexes connects your applications to external knowledge such as PDFs, Excel, Database etc
#     - Document loader: loads the data
#     - Text splitter: split into small chunks
#     - Vector store: create embeddings & store them
#     - Retrievars: when new query comes, It performs semantic search on vector store and returns the output
#
# 5. **Memory:** LLM API calls are stateless means Its doesnt remember previous conversation/ previous api conversation -- both api calls are independent. So we need a memory to store the previous conversations which goes along with next api call.
#
# 6. **Agents:** If LLM is able to understand conversation and answer correctly, so we can also have LLMs to perform the task like if we ask for cheapest flight in the morning, It can find and answer then we can also have it book the flight using reservation APIs abd payment systems. Thats an AI agent which can book flights.
#
# - AI agents are evolved version of chatbots which has access to the tools and reasoning capabilities.

# %% [markdown]
# ### 1. Models

# %% [markdown]
# ![image.png](attachment:image.png)
#
# In Langchain there are 2 types of models:
#
# 1. Language Models: text input and text output, helps to build chatbots
#     - LLMs: general purpose models means can be used for multiple tasks but they are old now
#     - Chat models: used for conversation tasks and they are new models
#
#     ![image-2.png](attachment:image-2.png)
#
# 2. Embedding models: text input vector output, helps to build semantic search apps

# %% [markdown]
# ```
# from langchain_openai import ChatOpenAI
# from dotenv import load_dotenv;load_dotenv()
#
# model = ChatOpenAI(model="gpt-4o-mini", temprature=0)
#
# result = model.invoke("what is the capital of india?")
# print(result.content)
# ```

# %% [markdown]
# - Unlike llms, chatmodel output will not just be plain text but much more detailed
#
# content='The capital of India is New Delhi.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 14, 'total_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b6580bbee1', 'id': 'chatcmpl-Dd8qToRLJJiUA6dFQdecxmKzC7vx3', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019e063d-a0dd-7bf0-99c9-213cb618eb02-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 14, 'output_tokens': 8, 'total_tokens': 22, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#
# - we can tune **temprature** to get consistent to creative output
# - temprature 0  give same output for same input everytime but if we increase the temparature then output will change for the same input
# - also we can tune **max_completion_tokens** to fix otuput tokens

# %% [markdown]
# #### open source vs closed source models

# %% [markdown]
# - **We can use closed source models like openai, anthropic, gemini etc but we can only use thier api and can not make any changes to the model whereas closed source models can be downloaded and we run it completly in our local pc**
#
# - Open source llms can be donloaded from huggingface, we can also use thier free tier api and try multiple models
# - Tu run model on local pc, we need very big configuration pc since it have huge number of parameters like in billions

# %% [markdown]
# #### embedding model

# %% [markdown]
# ```
# from langchain_openai import OpenAIEmbeddings
# from dotenv import load_dotenv;load_dotenv()
#
# embedding = OpenAIEmbeddings(model='text-embedding-3-small', dimensions=32)
# result = embedding.embed_query('delhi is capital of india')
#
# print(str(result))
#
#
# query = [
#     "my name is prashant jain",
#     "delhi is capital of india"
# ]
#
#
# result1 = embedding.embed_documents(query)
# print(str(result1))
#
#
#
# # output
# # [0.2352294921875, 0.06781005859375, 0.25927734375, 0.03887939453125, -0.2203369140625, 0.12274169921875, -0.1612548828125, 0.29248046875, -0.10357666015625, -0.032135009765625, 0.2161865234375, 0.111328125, -0.258544921875, -0.027374267578125, 0.1495361328125, -0.2388916015625, -0.187744140625, 0.08905029296875, 0.1241455078125, 0.2110595703125, 0.29541015625, 0.1571044921875, 0.2041015625, 0.1337890625, 0.259033203125, 0.21337890625, 0.00044655799865722656, -0.0126800537109375, 0.2144775390625, 0.0031719207763671875, -0.1905517578125, -0.0985107421875]
# # [[-0.0025424957275390625, -0.1624755859375, -0.1123046875, -0.0794677734375, -0.1453857421875, -0.267822265625, -0.08740234375, 0.306640625, -0.287109375, -0.1378173828125, 0.144287109375, -0.09771728515625, -0.153076171875, -0.029266357421875, 0.197265625, 0.058197021484375, -0.1890869140625, -0.26416015625, -0.0194854736328125, 0.12469482421875, 0.16455078125, -0.00513458251953125, 0.310791015625, 0.03375244140625, 0.176513671875, -0.2088623046875, 0.05029296875, 0.12445068359375, 0.1923828125, -0.271728515625, 0.306884765625, -0.132080078125], [0.2349853515625, 0.067626953125, 0.25927734375, 0.0389404296875, -0.2203369140625, 0.12261962890625, -0.1611328125, 0.292724609375, -0.103515625, -0.03204345703125, 0.216064453125, 0.111328125, -0.258544921875, -0.0274658203125, 0.149658203125, -0.2388916015625, -0.187255859375, 0.0888671875, 0.1241455078125, 0.210693359375, 0.295166015625, 0.1571044921875, 0.2037353515625, 0.1336669921875, 0.258544921875, 0.2135009765625, 0.00016009807586669922, -0.01287841796875, 0.21435546875, 0.003032684326171875, -0.1907958984375, -0.09820556640625]]
# ```

# %% [markdown]
# #### TEST: document similarity search app

# %% [markdown]
# **problem**
# - lets say we have 5 documents
# - user will ask a question and we will have to find out which of these document this question is related to
#
# **solution**
# - we will generate embedding of all documents & the question
# - find coside similarity between question vector and vectors of the docs
# - highest similarity score will be the answer

# %% [markdown]
# ### 2. Prompts

# %% [markdown]
# - Prompts are the input give to LLM to guide its output
#
# ![image.png](attachment:image.png)
#
# - Prompts can be text based or multimodal like image or audio or video
# - They are very sensitive becasue very slight change in prompt will change the output
# - Ideally in any app we develop, user will be passing the **static** input prompt which will be passed to LLM and get the output but since input prompt is very sensitive so we will not have any control over the output, model may halucinate and may not give the correct output or the consistent output which we want to provide to the user --> In order to control the output, we can use **dynamic prompts** using **langchain's prompt_template** to control the output.
#
# - Static prompt
#
# ```
# from langchain_openai import ChatOpenAI
# from dotenv import load_dotenv;load_dotenv()
# import streamlit as st
#
# model = ChatOpenAI(model="gpt-4o-mini", temprature=0, max_completion_tokens=10)
#
# st.header("Research Tool")
#
# user_input = st.text_input("Enter Your Prompt")
#
# if st.button("Summarize"):
#     result = model.invoke(user_input)
#     st.write("result.content")
# ```
#
# - Dynamic prompt
#
# ```
# from langchain_openai import ChatOpenAI
# from dotenv import load_dotenv;load_dotenv()
# import streamlit as st
# from langchain_core.prompts import PromptTemplate
#
# # Initialize model
# model = ChatOpenAI(
#     model="gpt-4o-mini",
#     temperature=0,
#     max_completion_tokens=300
# )
#
# # Streamlit UI
# st.set_page_config(page_title="Research Tool")
#
# st.header("Research Paper Summarizer")
#
# # Research paper selection
# paper_input = st.selectbox(
#     "Select Research Paper Name",
#     [
#         "Attention Is All You Need",
#         "BERT: Pre-training of Deep Bidirectional Transformers",
#         "GPT-3: Language Models are Few-Shot Learners"
#     ]
# )
#
# # Explanation style
# style_input = st.selectbox(
#     "Select Explanation Type",
#     [
#         "Beginner Friendly",
#         "Technical"
#     ]
# )
#
# # Explanation length
# length_input = st.selectbox(
#     "Select Explanation Length",
#     [
#         "Short (1-2 lines)",
#         "Medium (1-2 paragraphs)",
#         "Detailed(3 Paragraphs)"
#     ]
# )
#
# # Prompt Template
# template = PromptTemplate(
#     template="""
# You are a research paper expert.
#
# Explain the research paper "{paper_input}" in a {style_input} style.
#
# Keep the explanation {length_input}.
#
# Also explain:
# 1. Main idea of the paper
# 2. Key contribution
# 3. Real-world use case
# """,
#     input_variables=["paper_input", "style_input", "length_input"],
#     validate_input=True
# )
#
# # Generate prompt
# prompt = template.invoke({
#     "paper_input": paper_input,
#     "style_input": style_input,
#     "length_input": length_input
# })
#
# # Button action
# if st.button("Summarize"):
#
#     result = model.invoke(prompt)
#
#     st.subheader("Summary")
#     st.write(result.content)
# ```
#
#
# - **Why cant e just use f-strings in python?**
#     - Langchain's prompt input have default auto-validate feature unlike f-strings which allows empty also and gives error for empty input or extra input
#
#     - Reusable template: We can save the prompts in a file and use it in multiple code
#     - Prompt template is tightly coupled with Langchain ecosystem
#         - currently we are invoking twice: once for template and then again for model
#         - since its tightly coupled we can chain it and output of 1 stage becomes input for another
#
# ```
# from langchain_openai import ChatOpenAI
# from dotenv import load_dotenv;load_dotenv()
# import streamlit as st
# from langchain_core.prompts import PromptTemplate, load_prompt
#
# # Initialize model
# model = ChatOpenAI(
#     model="gpt-4o-mini",
#     temperature=0,
#     max_completion_tokens=300
# )
#
# # Streamlit UI
# st.set_page_config(page_title="Research Tool")
#
# st.header("Research Paper Summarizer")
#
# # Research paper selection
# paper_input = st.selectbox(
#     "Select Research Paper Name",
#     [
#         "Attention Is All You Need",
#         "BERT: Pre-training of Deep Bidirectional Transformers",
#         "GPT-3: Language Models are Few-Shot Learners"
#     ]
# )
#
# # Explanation style
# style_input = st.selectbox(
#     "Select Explanation Type",
#     [
#         "Beginner Friendly",
#         "Technical"
#     ]
# )
#
# # Explanation length
# length_input = st.selectbox(
#     "Select Explanation Length",
#     [
#         "Short (1-2 lines)",
#         "Medium (1-2 paragraphs)",
#         "Detailed(3 Paragraphs)"
#     ]
# )
#
#
# #load template
# template = load_prompt(r'D:\AgenticAI\Langchain_Models\2_prompts\template.json')
#
# # Button action
# if st.button("Summarize"):
#
#     chain = template | model
#     result = chain.invoke({
#         "paper_input": paper_input,
#         "style_input": style_input,
#         "length_input": length_input
#     })
#
#     st.subheader("Summary")
#     st.write(result.content)
# ```

# %% [markdown]
# #### Sample Project

# %% [markdown]
# ```
# from langchain_openai import ChatOpenAI
# from dotenv import load_dotenv;load_dotenv()
#
# # Initialize model
# model = ChatOpenAI(
#     model="gpt-4o-mini",
#     temperature=0,
#     max_completion_tokens=300
# )
#
# # Chat loop
# while True:
#     user_input = input("You: ")
#
#     if user_input.lower() == "exit":
#         print("Chat ended.")
#         break
#
#     # Invoke model
#     result = model.invoke(user_input)
#
#     # Print response
#     print(f"AI: {result.content}")
# ```
#
# - The issue with this chatbot is **Memory** -- It doesnt have context of previous chats
# - Thats why it fails when we ask information about previous chat
#
#
# ```
# from langchain_openai import ChatOpenAI
# from dotenv import load_dotenv;load_dotenv()
#
# # Initialize model
# model = ChatOpenAI(
#     model="gpt-4o-mini",
#     temperature=0,
#     max_completion_tokens=300
# )
#
# chat_history = []
#
# # Chat loop
# while True:
#     user_input = input("You: ")
#     chat_history.append(user_input)
#
#     if user_input.lower() == "exit":
#         print("Chat ended.")
#         break
#
#     # Invoke model
#     result = model.invoke(chat_history)     #----> sending chat history instead of user input
#
#     # Print response
#     print(f"AI: {result.content}")
# ```
#
#
# - Now we are mainting a list chat_history and sending that to the model instead of user_input
# - problem is that it doesnt know who said what !!
# - As chat history grows, It will become difficult for the LLM to understand who sent what and the responses will not be correct
# - Langchain has a builtin class already which does that
# - Langchain have 3 types of messages:
#     1. System messages
#     2. Human messages: which we send
#     3. AI messages: which ai replies
#
# ```
# from langchain_core.messages import SystemMessage, AIMessage, HumanMessage
# from langchain_openai import ChatOpenAI
# from dotenv import load_dotenv;load_dotenv()
#
# # Initialize model
# model = ChatOpenAI(
#     model="gpt-4o-mini",
#     temperature=0,
#     max_completion_tokens=300
# )
#
# messages = [
#     SystemMessage(content="You are a helpful assistant"),
#     HumanMessage(content="Tell me about langchain")
# ]
#
# result = model.invoke((messages))
# messages.append(AIMessage(content=result.content))
#
# print(messages)
# ```
#
# ![image.png](attachment:image.png)
#
#
#
# ```
# from langchain_openai import ChatOpenAI
# from dotenv import load_dotenv;load_dotenv()
# from langchain_core.messages import SystemMessage, AIMessage, HumanMessage
#
# # Initialize model
# model = ChatOpenAI(
#     model="gpt-4o-mini",
#     temperature=0,
#     max_completion_tokens=300
# )
#
# chat_history = [
#     SystemMessage(content="You are a helpful assistant"),
# ]
#
# # Chat loop
# while True:
#     user_input = input("You: ")
#     chat_history.append(HumanMessage(content=user_input))
#
#     if user_input.lower() == "exit":
#         print("Chat ended.")
#         break
#
#     # Invoke model
#     result = model.invoke(chat_history)
#     chat_history.append(AIMessage(content=result.content))
#
#     # Print response
#     print(f"AI: {result.content}")
#
#
# print(chat_history)
#
#
#
#
# # (venv) D:\AgenticAI\Langchain_Models>py 2_prompts\chatbot.py
# # You: hi
# # AI: Hello! How can I assist you today?
# # You: who created you in short
# # AI: I was created by OpenAI, an artificial intelligence research organization. If you have any specific questions about my capabilities or how I work, feel free to ask!
# # You: exit
# # Chat ended.
# # [SystemMessage(content='You are a helpful assistant', additional_kwargs={}, response_metadata={}), HumanMessage(content='hi', additional_kwargs={}, response_metadata={}), AIMessage(content='Hello! How can I assist you today?', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='who created you in short', additional_kwargs={}, response_metadata={}), AIMessage(content='I was created by OpenAI, an artificial intelligence research organization. If you have any specific questions about my capabilities or how I work, feel free to ask!', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='exit', additional_kwargs={}, response_metadata={})]
#
# # (venv) D:\AgenticAI\Langchain_Models>
#
# ```
#
# - **NOW with this each of our messages are labelled about who sent it so when chat history grows, model doesnt get confused**

# %% [markdown]
# #### ChatPromptTemplate

# %% [markdown]
# - To create dynamic set of messages
#
# ```
# from langchain_core.prompts import ChatPromptTemplate
# from dotenv import load_dotenv
# load_dotenv()
#
# # FIX: use tuple format instead of SystemMessage/HumanMessage objects
# chat_template = ChatPromptTemplate.from_messages([
#     ("system", "You are a helpful {domain} expert"),
#     ("human", "Explain in simple terms, what is {topic}")
# ])
#
# # Invoke template
# prompt = chat_template.invoke({
#     "domain": "cricket",
#     "topic": "doosra"
# })
#
# # Print formatted messages
# print(prompt)
# ```

# %% [markdown]
# #### message placeholder

# %% [markdown]
# - Lets say we created a chatbot for amazon, user came and ask for refund - chatbot replied its done and will reflect in 2-3 days. After 2-3 user comes back and says where is my refund -- now chatbot will not know about previous conversation unless we create a chathistory.
#
# - we use **message placeholder** to save the chat history

# %% [markdown]
# ### 3. Structured output in Langchain

# %% [markdown]
# - By default, LLMs return responses in free-form, unstructured text. **Structured Output** in LangChain ensures that responses are generated in a predefined format such as JSON, making them easier to parse and use programmatically.
#
# - It will be easier for
#     1. data extarction
#     2. API building
#     3. AI Agents etc
#
# ![image.png](attachment:image.png)
#
# - There are 2 type of LLMs
#     1. LLMs which can return strucutred output
#     2. LLMs which can not return structured output

# %% [markdown]
# #### 1. With structured output function

# %% [markdown]
# - Before model invoke we need to call ith strucutred output function and provide data format
# - There are 3 types to specify data format
#     1. Typed dict
#     2. Pydantic
#     3. Json_Schema

# %% [markdown]
# #### 1. Typedict

# %% [markdown]
# - **Typed dict**
#     - Its a way to define a dictionary in python where you specify what keys and values should exist
#     - It helps to ensure that dictionary follows a specific structure
#     - It tells what keys are required and what type of values they should have
#     - It doesnt validate, It just tells us but even if you provide a wrong dtype then will not throw error
#
#
# ```
# from langchain_openai import ChatOpenAI
# from dotenv import load_dotenv;load_dotenv()
# from typing import TypedDict, Annotated
#
# model = ChatOpenAI(
#     model="gpt-4o-mini",
#     temperature=0,
#     max_completion_tokens=100
# )
#
# # Schema
# class Review(TypedDict):
#     summary: str
#     sentiment: str
#
#     # float score between -1 and 1
#     sentiment_score: Annotated[
#         float,
#         "Sentiment score ranging from -1 (very negative) to 1 (very positive)"
#     ]
#
# structured_model = model.with_structured_output(Review)
#
# result = structured_model.invoke(
#     "Great service, friendly staff, and excellent experience overall. Highly recommended!"
# )
#
# print(result)
#
# {'summary': 'Great service, friendly staff, and excellent experience overall. Highly recommended!', 'sentiment': 'positive', 'sentiment_score': 0.95}
# ```
#
#
# - When we use structured output, In backend it generates a prompt to return output in same strucutred schema without even asking anything about sentiment, sentiment score or summary since that's how the structured schema was defined it returns the output in the same way
#
# - Use **Annotated** to define the exact output needed from LLM without it getting hallucinated
#
#
# ```
# from langchain_openai import ChatOpenAI
# from dotenv import load_dotenv;load_dotenv()
# from typing import TypedDict, Annotated
#
# model = ChatOpenAI(model="gpt-4o-mini")
#
# # Schema
# class Review(TypedDict):
#     # Exact text copied from the review only
#     sentiment_reason: Annotated[
#         str,
#         "Exact line or phrase from the review responsible for the sentiment. Do not generate or paraphrase."
#     ]
#
#     sentiment: str
#
#     sentiment_score: Annotated[
#         float,
#         "Sentiment score ranging from -1 (very negative) to 1 (very positive)"
#     ]
#
#
# structured_model = model.with_structured_output(Review)
#
# result = structured_model.invoke(
#     "Great service, friendly staff, and excellent experience overall. Highly recommended!"
# )
#
# print(result)
#
# import pdb;pdb.set_trace()
# ```
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 2. Pydantic

# %% [markdown]
# - Its a data validation and data parsing library in python
# - We use it in FastAPI to make sure input data types are correct
#
# ```
# from langchain_openai import ChatOpenAI
# from dotenv import load_dotenv;load_dotenv()
# from pydantic import BaseModel, Field
#
#
# model = ChatOpenAI(model="gpt-4o-mini")
#
# # Schema
# class Review(BaseModel):
#     key_themes: list[str] = Field(
#         description="All key themes in broader way discussed in the review"
#     )
#
#     sentiment_reason: list[str] = Field(
#         description="Exact phrases from the review responsible for the sentiment. Do not paraphrase or generate new text."
#     )
#
#     sentiment_score: list[float] = Field(
#         description="Sentiment score for the review ranging between -1 and 1"
#     )
#
#
# structured_model = model.with_structured_output(Review)
#
# result = structured_model.invoke(
#     "Great service, friendly staff, and excellent experience overall. Highly recommended!"
# )
#
# print(result)
#
# import pdb;pdb.set_trace()
# ```

# %% [markdown]
# #### 3. JSON

# %% [markdown]
# - Json is a universal data format
# - When we are using 2 different languages like python and javascript then we cant use pydantic
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# - When calling **strucuted output function** we can define which **method** to use:
#     1. json: when output needed in json
#     2. function calling: when we want to use a funtion or tool like in AI agents
#     - when using OpenAI models, use function calling as it is default

# %% [markdown]
# ### 4. Output Parsers

# %% [markdown]
# - Helps to convert raw text based llm responses into structured formats
# - It works with LLMs which do or doesnt by default return structured output
#     1. StrOutputParser
#     2. JSONOutputParser
#     3. StructuredOutputParser
#     4. PydanticOutputParser

# %% [markdown]
# #### 1. string output parser

# %% [markdown]
# ```
# from langchain_openai import ChatOpenAI
# from dotenv import load_dotenv
# from langchain_core.prompts import PromptTemplate
# from langchain_core.output_parsers import StrOutputParser
#
#
# load_dotenv()
#
# # OpenAI Model
# model = ChatOpenAI(model="gpt-4o-mini")
#
# # 1st prompt --> detailed report
# template1 = PromptTemplate(
#     template="Write a report on {topic} in maximum 2 lines",
#     input_variables=['topic']
# )
#
# # 2nd prompt --> summary
# template2 = PromptTemplate(
#     template="Write a 1 line summary on {text}",
#     input_variables=['text']
# )
#
# parser = StrOutputParser()
# #stroutputparser is helpful to make chains otherwise we will be doing it seperatly
#
# chain = template1 | model | parser | template2 | model | parser
# result = chain.invoke({'topic':'black_hole'})
# print(result)
# ```

# %% [markdown]
# #### 2. json output parser

# %% [markdown]
# - Forces llm to return output in json
#
# ```
# from langchain_openai import ChatOpenAI
# from dotenv import load_dotenv
# from langchain_core.prompts import PromptTemplate
# from langchain_core.output_parsers import JsonOutputParser
#
# load_dotenv()
#
# # OpenAI Model
# model = ChatOpenAI(model="gpt-4o-mini")
#
# parser = JsonOutputParser()
#
# template = PromptTemplate(
#     template="""
#     Give me name, age & city of a fictional person.
#
#     {format_instructions}
#     """,
#
#     input_variables=[],
#
#     partial_variables={
#         'format_instructions': parser.get_format_instructions()
#     }
# )
#
# prompt = template.format()
#
# print(prompt)
# ```
#
# - **CONS** we can not impose schema of json object, It completly depends on llm
# - we can use **structured output parser** to define a schema we want  in output

# %% [markdown]
# #### structured output parser

# %% [markdown]
# ```
# from langchain_openai import ChatOpenAI
# from dotenv import load_dotenv;load_dotenv()
# from langchain_core.prompts import PromptTemplate
# from langchain.output_parsers import StructuredOutputParser, ResponseSchema
#
# # OpenAI Model
# model = ChatOpenAI(model="gpt-4o-mini")
#
# schema = [
#     ResponseSchema(name='fact_1', description='Fact 1 about the topic'),
#     ResponseSchema(name='fact_2', description='Fact 2 about the topic'),
#     ResponseSchema(name='fact_3', description='Fact 3 about the topic'),
# ]
#
# parser = StructuredOutputParser.from_response_schemas(schema)
#
# template = PromptTemplate(
#     template="Give 3 facts about {topic} \n {format_instructions}",
#
#     input_variables=['topic'],
#
#     partial_variables={
#         'format_instructions': parser.get_format_instructions()
#     }
# )
#
# prompt = template.invoke({'topic': 'black hole'})
# result = model.invoke(prompt)
# final_result = parser.parse(result.content)
# print(final_result)
# ```
#
# - **cons**
# - Although it enforces schema but No data validation means if we want age as integer and model returns str. There is no way to force that --> To avoid this we can use **PydanticOutputParser**

# %% [markdown]
# #### PydanticOutputParser

# %% [markdown]
# - Its a structured output parser in langchain that uses pydantic models to enforce schema & data validation when processing llm responses
#
# ```
# from langchain_openai import ChatOpenAI
# from dotenv import load_dotenv
# from langchain_core.prompts import PromptTemplate
# from langchain_core.output_parsers import PydanticOutputParser
# from pydantic import BaseModel, Field
#
# load_dotenv()
#
# # OpenAI Model
# model = ChatOpenAI(model="gpt-4o-mini")
#
#
# class Person(BaseModel):
#     name: str = Field(description='Name of the person')
#
#     age: int = Field(
#         gt=18,
#         description='Age of the person'
#     )
#
#     city: str = Field(
#         description='City where the person lives'
#     )
#
#
# parser = PydanticOutputParser(pydantic_object=Person)
#
# template = PromptTemplate(
#     template="""
#     Generate name, age, and city of a fictional {place} person.
#
#     {format_instructions}
#     """,
#
#     input_variables=['place'],
#
#     partial_variables={
#         'format_instructions': parser.get_format_instructions()
#     }
# )
#
# prompt = template.invoke({'place': 'Indian'})
# print(prompt)
#
# # result = model.invoke(prompt)
#
# # final_result = parser.parse(result.content)
#
# # print(final_result)
#
#
# chain = template | model | parser
# final_result = chain.invoke({'place': 'malaysian'})
# print(final_result)
# ```

# %% [markdown]
# ### 5. Chain

# %% [markdown]
# #### Recap

# %% [markdown]
# 1. Models: How to use different type of models open source or close source in Langchain
# 2. Prompts: How to send inputs to langchain in different way
# 3. How to generate structured output and output parsers

# %% [markdown]
# #### fundamentals

# %% [markdown]
# - When we are building applications using LLM, Its built with adding small steps like:
#     1. user gives input prompt
#     2. sending it to llm
#     3. sending llm response to user
#
# - **prompt --> llm --> output**
# - If we will do it manually like handling each component and asigning output of 1 component as input for net component --> This is not efficient
# - We can use **Chain** which will act as a pipeline and auto asign the output as input for next component
# - We can just give input which will trigger all component and finally we will get the output
# - We can also do parallel processing and make complex pipelines uising chain

# %% [markdown]
# #### simple chain

# %% [markdown]
# ```
# from langchain_openai import ChatOpenAI
# from dotenv import load_dotenv; load_dotenv()
# from langchain_core.prompts import PromptTemplate
# from langchain_core.output_parsers import StrOutputParser
#
# prompt = PromptTemplate(
#     template = "generate 2 interesting facts about {topic}",  # Fixed typo
#     input_variables = ['topic']
# )
#
# model = ChatOpenAI(model="gpt-4o-mini")
# parser = StrOutputParser()
#
# # "|" is called LCEL (langchain expression language)
# chain = prompt | model | parser
# chain.get_graph().print_ascii()
#
# result = chain.invoke({'topic': 'cricket'})
# print(result)
#
#
# +-----------------+
# | PromptTemplate  |
# +-----------------+
#         *
#         *
#         *
#    +----------+
#    | ChatOpenAI |
#    +----------+
#         *
#         *
#         *
# +------------------+
# | StrOutputParser  |
# +------------------+
# ```

# %% [markdown]
# #### complex chain

# %% [markdown]
# ```
# from langchain_openai import ChatOpenAI
# from dotenv import load_dotenv;load_dotenv()
# from langchain_core.prompts import PromptTemplate
# from langchain_core.output_parsers import StrOutputParser
#
# prompt1 = PromptTemplate(
#     template="""
#     Generate exactly 2 Google reviews about {topic}.
#
#     Rules:
#     - Each review must be on a separate line
#     - Each review should be only 1 line
#     - Do not add numbering
#     - Do not add explanations
#     """,
#
#     input_variables=['topic']
# )
#
# prompt2 = PromptTemplate(
#     template="""
#     For each review below, generate a sentiment score between -1 and 1.
#
#     Return output in this format:
#     Review: <review>
#     Score: <score>
#
#     Reviews:
#     {text}
#     """,
#
#     input_variables=['text']
# )
#
# model = ChatOpenAI(model="gpt-4o-mini")
# parser = StrOutputParser()
#
# chain = (
#     prompt1
#     | model
#     | parser
#     | (lambda x: {"text": x})
#     | prompt2
#     | model
#     | parser
# )
#
# result = chain.invoke({'topic': 'Fogo de Chão'})
#
# # (Pdb) result
# # 'Review: The steak selection at Fogo de Chão is outstanding, with perfectly cooked meats that are full of flavor.  \nScore: 1\n\nReview: Fogo de Chão offers an incredible dining experience with attentive service and a vibrant atmosphere.  \nScore: 1'
# ```

# %% [markdown]
# #### parallel chain

# %% [markdown]
# ```
# from langchain_openai import ChatOpenAI
# from langchain_anthropic import ChatAnthropic
# from dotenv import load_dotenv;load_dotenv()
# from langchain_core.prompts import PromptTemplate
# from langchain_core.output_parsers import StrOutputParser
# from langchain.schema.runnable import RunnableParallel  #to execute chains parallely
#
# model1 = ChatOpenAI(model="gpt-4o-mini")
# model2 = ChatAnthropic(model_name="claude-3")
#
# parser = StrOutputParser()
#
# prompt1 = PromptTemplate(
#     template = "generate short and simple notes from folloing text \n {text}",
#     input_variables=['text']
# )
#
# prompt2 = PromptTemplate(
#     template = "generate 5 short questions and answers from the following \n {text}",
#     input_variables=['text']
# )
#
#
# prompt3 = PromptTemplate(
#     template = "merge provided notes and quiz into single document \n notes -> {notes} and quiz -> {quiz}",
#     input_variables=['notes', 'quiz']
# )
#
# parallel_chain = RunnableParallel({
#     'notes': prompt1 | model1 | parser,
#     'quiz': prompt2 | model2 | parser,
# })
#
# merge_chain = prompt3 | model1 | parser
#
# chain = parallel_chain | merge_chain
#
# text = """## Support Vector Machine (SVM) – A Short Note
#
# A **Support Vector Machine (SVM)** is a supervised machine learning algorithm used primarily for **classification** and also for regression tasks (SVR). Its core idea is to find the optimal **hyperplane** that best separates data points of different classes in a high-dimensional space.
#
# ### How It Works
# - In a two-class problem, SVM identifies the hyperplane that maximizes the **margin** – the distance between the hyperplane and the nearest data points from each class.
# - These closest points are called **support vectors**. They alone define the decision boundary.
# - If data is not linearly separable, SVM uses **kernel functions** (e.g., linear, polynomial, RBF) to map data into a higher dimension where a clear separation is possible.
#
# ### Key Features
# - **Effective in high dimensions** – works well even when number of features exceeds samples.
# - **Memory efficient** – only support vectors are retained after training.
# - **Versatile** – different kernels allow handling of complex, non-linear boundaries.
# - **Sensitive to scaling** – feature normalization is essential.
# - **Not ideal for very large datasets** – training time can be high.
#
# ### Common Applications
# Text classification, image recognition, bioinformatics (e.g., protein classification), and handwriting recognition.
#
# In short, SVM is a powerful, geometry-driven classifier known for its accuracy and robustness, especially in moderate-sized, high-dimensional problems."""
#
# result = chain.invoke({'text':text})
# print(result)
# ```

# %% [markdown]
# #### conditional chain

# %% [markdown]
# - We will build an App for Amazon where user gives feedback for any product
# - We will analyze and find the sentiment of it
#     - If its positive then reply for positive sentiment
#     - If its negative then reply for negative sentiment
#
#
# ```
# from langchain_openai import ChatOpenAI
# from langchain_anthropic import ChatAnthropic
# from dotenv import load_dotenv; load_dotenv()
# from langchain_core.prompts import PromptTemplate
# from langchain_core.output_parsers import StrOutputParser, PydanticOutputParser
# from langchain.schema.runnable import RunnableParallel, RunnableBranch, RunnableLambda
# from pydantic import BaseModel, Field
# from typing import Literal
#
#
# model = ChatOpenAI(model="gpt-4o-mini")
# parser1 = StrOutputParser()
#
# class Feedback(BaseModel):
#     sentiment: Literal['positive', 'negative'] = Field(description="give the sentiment of the feedback")
#
# parser2 = PydanticOutputParser(pydantic_object=Feedback)
#
# prompt1 = PromptTemplate(
#     template = "classify the sentiment of the following feedback into positive or negative \n {feedback} \n {format_instructions}",
#     input_variables = ['feedback'],
#     partial_variables = {'format_instructions': parser2.get_format_instructions()}
# )
#
# classifier_chain = prompt1 | model | parser2
#
# prompt2 = PromptTemplate(
#     template = "write an appropriate response to this positive feedback \n {feedback}",
#     input_variables=['feedback']
# )
#
# prompt3 = PromptTemplate(
#     template = "write an appropriate response to this negative feedback \n {feedback}",
#     input_variables=['feedback']
# )
#
# branch_chain = RunnableBranch(
#     (lambda x: x['sentiment'] == 'positive', prompt2 | model | parser1),
#     (lambda x: x['sentiment'] == 'negative', prompt3 | model | parser1),
#     RunnableLambda(lambda x: "No sentiment found")
# )
#
# # Fix: Transform Feedback object to dict before passing to branch_chain
# chain = classifier_chain | RunnableLambda(lambda fb: {'sentiment': fb.sentiment, 'feedback': fb.feedback}) | branch_chain
#
# result = chain.invoke({'feedback':'this is terrible phone'})
# print(result)
# ```

# %% [markdown]
# ### 6. Runnables

# %% [markdown]
# #### Why

# %% [markdown]
# - Chain in Langchain enables three core execution flows:
#     1. **Sequential** – step-by-step chain execution
#     2. **Parallel** – concurrent runs of multiple chains
#     3. **Conditional** – logic-based branching
#
# - Efficient chaining requires a solid grasp of **runnables**.
#
# - When ChatGPT launched its public APIs in 2022, businesses rapidly adopted them to build chatbots.
# Recognizing the growing need for LLM-based apps, LangChain created a unified framework that supports any LLM with minimal code changes.
#
# - LangChain gained popularity because LLM interaction is just the start—it also handles **data loading, embeddings, and semantic search** seamlessly.
#
# ![image.png](attachment:image.png)
#
# - LangChain expanded beyond core execution by building helper functions for each component, making it a powerful library.
#
# **Prompt** is common across all LLM apps — this led to the introduction of **Chain**.
#
# - For RAG-based applications, **retrieval** is a recurring need. LangChain integrated all retrieval stages into the **Retriever QA Chain**.
#
# - LangChain has since developed multiple specialized chains for common tasks.
#
# ![image-2.png](attachment:image-2.png)
#
# - Over time, LangChain introduced many chains, increasing complexity for new learners.
#
# - Components were developed independently and lacked standardization, leading to inconsistent behavior. This forced the team to create custom chain functions like `LLMChain`, `PromptChain`, and `QAChain`.
#
# - To enable seamless component integration, LangChain introduced **Runnables** — a unified interface for building and connecting chains consistently.

# %% [markdown]
# #### What

# %% [markdown]
# ![image.png](attachment:image.png)
#
# - Runnables are a unit of work, which means:
#     1. We can give an **input**
#     2. It will **process**
#     3. Returns an **output**
#
# - Each runnable follows a common interface
#     1. invoke
#     2. batch
#     3. stream
#
# - Each runnable can be connected together, which makes output of 1st runnable becomes input for next runnable
#
# - Each runnble workflow is itself a runnable
#
# - Runnables are same as **Lego blocks**

# %% [markdown]
# #### how 1

# %%
import random

class NakliLLM:

  def __init__(self):
    print('LLM created')

  def predict(self, prompt):

    response_list = [
        'Delhi is the capital of India',
        'IPL is a cricket league',
        'AI stands for Artificial Intelligence'
    ]

    return {'response': random.choice(response_list)}

# %%
class NakliPromptTemplate:

  def __init__(self, template, input_variables):
    self.template = template
    self.input_variables = input_variables

  def format(self, input_dict):
    return self.template.format(**input_dict)

# %%
template = NakliPromptTemplate(
    template='Write a {length} poem about {topic}',
    input_variables=['length', 'topic']
)

# %%
prompt = template.format({'length':'short','topic':'india'})

# %%
llm = NakliLLM()
# Out:
# LLM created

# %%
llm.predict(prompt)
# Out:
# {'response': 'AI stands for Artificial Intelligence'}

# %%
class NakliLLMChain:

  def __init__(self, llm, prompt):
    self.llm = llm
    self.prompt = prompt

  def run(self, input_dict):

    final_prompt = self.prompt.format(input_dict)
    result = self.llm.predict(final_prompt)

    return result['response']

# %%
template = NakliPromptTemplate(
    template='Write a {length} poem about {topic}',
    input_variables=['length', 'topic']
)

# %%
llm = NakliLLM()
# Out:
# LLM created

# %%
chain = NakliLLMChain(llm, template)

# %%
chain.run({'length':'short', 'topic': 'india'})
# Out:
# 'Delhi is the capital of India'

# %% [markdown]
# #### how 2

# %%
from abc import ABC, abstractmethod

# %%
class Runnable(ABC):

  @abstractmethod
  def invoke(input_data):
    pass

# %%
import random

class NakliLLM(Runnable):

  def __init__(self):
    print('LLM created')

  def invoke(self, prompt):
    response_list = [
        'Delhi is the capital of India',
        'IPL is a cricket league',
        'AI stands for Artificial Intelligence'
    ]

    return {'response': random.choice(response_list)}


  def predict(self, prompt):

    response_list = [
        'Delhi is the capital of India',
        'IPL is a cricket league',
        'AI stands for Artificial Intelligence'
    ]

    return {'response': random.choice(response_list)}

# %%
class NakliPromptTemplate(Runnable):

  def __init__(self, template, input_variables):
    self.template = template
    self.input_variables = input_variables

  def invoke(self, input_dict):
    return self.template.format(**input_dict)

  def format(self, input_dict):
    return self.template.format(**input_dict)

# %%
class NakliStrOutputParser(Runnable):

  def __init__(self):
    pass

  def invoke(self, input_data):
    return input_data['response']

# %%
class RunnableConnector(Runnable):

  def __init__(self, runnable_list):
    self.runnable_list = runnable_list

  def invoke(self, input_data):

    for runnable in self.runnable_list:
      input_data = runnable.invoke(input_data)

    return input_data

# %%
template = NakliPromptTemplate(
    template='Write a {length} poem about {topic}',
    input_variables=['length', 'topic']
)

# %%
llm = NakliLLM()
# Out:
# LLM created

# %%
parser = NakliStrOutputParser()

# %%
chain = RunnableConnector([template, llm, parser])

# %%
chain.invoke({'length':'long', 'topic':'india'})
# Out:
# 'Delhi is the capital of India'

# %%
template1 = NakliPromptTemplate(
    template='Write a joke about {topic}',
    input_variables=['topic']
)

# %%
template2 = NakliPromptTemplate(
    template='Explain the following joke {response}',
    input_variables=['response']
)

# %%
llm = NakliLLM()
# Out:
# LLM created

# %%
parser = NakliStrOutputParser()

# %%
chain1 = RunnableConnector([template1, llm])

# %%
chain2 = RunnableConnector([template2, llm, parser])

# %%
final_chain = RunnableConnector([chain1, chain2])

# %%
final_chain.invoke({'topic':'cricket'})
# Out:
# 'IPL is a cricket league'

# %% [markdown]
# #### Types of Runnables

# %% [markdown]
# 1. **Task specific:** These are core langchain components that have been converted into **Runnables** so they can be used in pipelines to perform task specific operataions like LLM calls, prompting, retrievals etc like ChatOpenAI, PromptTemplate, Retriever
#
# 2. **Runnable premitives:** Runnable connectors which can be used to execute workflows are runnable premitives like RunnableSequence, RunnableParallel, RunnableMap, RunnableBranch, RunnableLambda, RunnablePassthrough

# %% [markdown]
# ##### RunnableSequence

# %% [markdown]
# - To connect 2 or more then 2 runnables sequentially, It passes output of 1 step as input to next step
#
# ![image.png](attachment:image.png)
#
# ```
# from langchain_openai import ChatOpenAI
# from langchain_core.prompts import PromptTemplate
# from langchain_core.output_parsers import StrOutputParser
# from dotenv import load_dotenv; load_dotenv()
# from langchain_core.runnables import RunnableSequence
#
# # Runnable 1: Generate a joke
# prompt1 = PromptTemplate(
#     template="write a 1 line joke about {topic}",
#     input_variables=['topic']
# )
#
# model = ChatOpenAI(model="gpt-4o-mini")
# parser = StrOutputParser()
#
# # Runnable 2: Explain the joke
# prompt2 = PromptTemplate(
#     template="explain the following joke in 2 words: {text}",
#     input_variables=['text']
# )
#
# # Create the chain
# chain = RunnableSequence(prompt1, model, parser, prompt2, model, parser)
#
# # Invoke
# result = chain.invoke({'topic': 'AI'})
# print(result)
# ```

# %% [markdown]
# ##### RunnableParallel

# %% [markdown]
# - To execute runnables in parallel instead of sequentially

# %% [markdown]
# ```
# from langchain_openai import ChatOpenAI
# from langchain_core.prompts import PromptTemplate
# from langchain_core.output_parsers import StrOutputParser
# from dotenv import load_dotenv; load_dotenv()
# from langchain_core.runnables import RunnableSequence, RunnableParallel
#
# model = ChatOpenAI(model="gpt-4o-mini")
# parser = StrOutputParser()
#
# prompt1 = PromptTemplate(
#     template = 'generate a 1 line short tweet about {topic}',
#     input_variables = ['topic']
# )
#
# prompt2 = PromptTemplate(
#     template = 'generate a linkedin post in short about {topic}',
#     input_variables = ['topic']
# )
#
# parallel_chain = RunnableParallel({
#     'tweet': RunnableSequence(prompt1, model, parser),
#     'linkedin_post': RunnableSequence(prompt2, model, parser),
# })
#
# result = parallel_chain.invoke({'topic':'AI'})
# print(result)
#
#
# import pdb;pdb.set_trace()
# ```

# %% [markdown]
# ##### RunnablePassthrough

# %% [markdown]
# - It simply returns the input as output
# - Its useful in cases where we also want to return the output of middle steps because in chains we get to see the final output only

# %% [markdown]
# ```
# from langchain_openai import ChatOpenAI
# from langchain_core.prompts import PromptTemplate
# from langchain_core.output_parsers import StrOutputParser
# from dotenv import load_dotenv; load_dotenv()
# from langchain_core.runnables import RunnableSequence, RunnableParallel, RunnablePassthrough
#
# model = ChatOpenAI(model="gpt-4o-mini")
# parser = StrOutputParser()
#
# prompt1 = PromptTemplate(
#     template = 'generate a 1 line short tweet about {topic}',
#     input_variables = ['topic']
# )
#
# prompt2 = PromptTemplate(
#     template = 'generate a linkedin post in short about {topic}',
#     input_variables = ['topic']
# )
#
# joke_gen_chain = RunnableSequence(prompt1, model, parser)
# parallel_chain = RunnableParallel({
#     'joke':RunnablePassthrough,
#     'explanation':RunnableSequence(prompt2, model, parser)
# })
#
#
# final_chain = RunnableSequence(joke_gen_chain, parallel_chain)
# result = final_chain.invoke()
#
#
# import pdb;pdb.set_trace()
# ```

# %% [markdown]
# ##### Runnable Lambda

# %% [markdown]
# - Runnable lambda is a runnable primitive that allows you to apply custom python functions within AI pipeline
#
# - We can add our own cleaning, preprocessing, transformation, filtering etc in AI workflow
# - Lets find out the no. of words of joke in the joke example
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ```
# from langchain_openai import ChatOpenAI
# from langchain_core.prompts import PromptTemplate
# from langchain_core.output_parsers import StrOutputParser
# from dotenv import load_dotenv; load_dotenv()
# from langchain_core.runnables import RunnableParallel, RunnablePassthrough, RunnableLambda, RunnableSequence
#
# model = ChatOpenAI(model="gpt-4o-mini")
# parser = StrOutputParser()
#
# prompt1 = PromptTemplate(
#     template='generate a 1 line short joke about {topic}',
#     input_variables=['topic']
# )
#
#
# prompt2 = PromptTemplate(
#     template='explain this joke in 2 words: {joke}',
#     input_variables=['joke']
# )
#
# joke_gen_chain = RunnableSequence(prompt1, model, parser)
#
# parallel_chain = ({
#     'joke':RunnablePassthrough,
#     'word_counter':RunnableLambda(lambda x:len(x.split())),
# })
#
# final_chain=RunnableSequence(joke_gen_chain, parallel_chain)
# result = final_chain.invoke({'topic':'AI'})
# print(result)
#
# ```

# %% [markdown]
# ##### RunnableBranch

# %% [markdown]
# - Used for conditional chains
# - We are recieving email and we want to find out whether this email is for customer service, billing/refunds or escalation and then forward it to respective team

# %% [markdown]
# Workflow: Email - Prompt - Generate Category - RunnableBranch
#
#     1. how to handle complain
#     2. how to handle billings
#     3. how to handle general query

# %% [markdown]
# ```
# from langchain_openai import ChatOpenAI
# from langchain_core.prompts import PromptTemplate
# from langchain_core.output_parsers import StrOutputParser
# from dotenv import load_dotenv; load_dotenv()
# from langchain_core.runnables import RunnableParallel, RunnablePassthrough, RunnableLambda, RunnableSequence, RunnableBranch
#
# model = ChatOpenAI(model="gpt-4o-mini")
# parser = StrOutputParser()
#
# prompt1 = PromptTemplate(
#     template = "write a detailed report on {topic}",
#     input_variables = ['topic']
# )
#
#
# prompt2 = PromptTemplate(
#     template = "summarize the following {text}",
#     input_variables = ['text']
# )
#
# report_gen_chain = RunnableSequence(prompt1, model, parser)
#
# branch_chain = RunnableBranch(
#     (lambda x:len(x.split()) > 500),RunnableSequence(prompt2, model, parser),
#     RunnablePassthrough()
#     )
#
#
# final_chain = RunnableSequence(report_gen_chain, branch_chain)
#
# result = final_chain.invoke({
#     'topic':'russia vs ukraine'
# })
#
# print(result)
# ```

# %% [markdown]
# ##### LCEL (LangChain Expression Language)

# %% [markdown]
# - RunnableSequence is most common premitive which is used in most cases
# - Thats why langchain team thought to make it more simpler which can be used with minimal code
# - We can use pipe operator instead
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - **Instead of this: report_gen_chain = RunnableSequence(prompt1, model, parser)**
#
# - **We can use this: report_gen_chain = prompt1 | model | parser**

# %% [markdown]
# ### 7. RAG based applicatins using LangChain

# %% [markdown]
# - Till now we have covered Models, Prompts, Chains, Runnables
# - We can now build RAG based applications using LangChain
# - Chatgpt can answer most of the general questions on which it is trained but it fails on **Personal Data**
# - **RAG based applications** help where we give chatgpt access to external knowledge like PDF, Dbs etc
# - RAG is a technique that combines information retrieval with language generation where model retrievs relevant documents from a knoledge base and then uses that as context to generate accurate and grounded response.
# - There is no limit on document or external knowledge size unlinke chatgpt where we can uplaod a pdf to get answers but not whole adtabase or not 100s of pdfs

# %% [markdown]
# #### Components of RAG based applications

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 1. Document Loaders

# %% [markdown]
# - Document laoders is a components in LangChain which is used to load data from various sources into standard format as *document object* which can then be used for chunking, embedding, retrieval and generation
#
# 1. text loader
# 2. pdf loader
# 3. web base loader
# 4. csv loader

# %% [markdown]
# ##### Text Loader

# %% [markdown]
# ```
# from langchain_community.document_loaders import TextLoader
#
# loader = TextLoader(r'D:\AgenticAI\4_Document_loaders\cricket.txt', encoding = 'utf-8')
# docs = loader.load()
#
# print(docs)
# ```
#
# - It always loads document in list
#
# ```
# from langchain_community.document_loaders import TextLoader
# from langchain_openai import ChatOpenAI
# from langchain_core.output_parsers import StrOutputParser
# from langchain_core.prompts import PromptTemplate
# from dotenv import load_dotenv;load_dotenv()
#
# model=ChatOpenAI(model='gpt-4o-mini')
# parser=StrOutputParser()
#
# prompt=PromptTemplate(
#     template='write a summary for following {text}',
#     input_variables=['text']
# )
#
# loader = TextLoader(r'D:\AgenticAI\4_Document_loaders\cricket.txt', encoding = 'utf-8')
# docs = loader.load()
#
# # print(docs)
# # print(docs[0])
# # print(docs[0].page_content)
# # print(docs[0].metadata)
#
# chain = prompt | model | parser
# result = chain.invoke({'text':docs[0].page_content})
# print(result)
# ```

# %% [markdown]
# ##### Pypdf Loader

# %% [markdown]
# - It loads content from pdf files and convert each page into a document obect
# - It works on page by page basis means for 25 pages pdf will have 25 document obect
# - It uses pypdf library in backend so not good wwith scanned pdfs or complex layout pdfs

# %% [markdown]
# ```
# from langchain_community.document_loaders import PyPDFLoader
# from langchain_openai import ChatOpenAI
# from langchain_core.output_parsers import StrOutputParser
# from langchain_core.prompts import PromptTemplate
# from dotenv import load_dotenv;load_dotenv()
#
# model=ChatOpenAI(model='gpt-4o-mini')
# parser=StrOutputParser()
#
# prompt=PromptTemplate(
#     template='write a summary for following {text}',
#     input_variables=['text']
# )
#
# loader = PyPDFLoader(r"D:\AgenticAI\4_Document_loaders\dl-curriculum.pdf")
# docs = loader.load()
#
# print(docs)
# # print(docs[0])
# # print(docs[0].page_content)
# # print(docs[0].metadata)
#
# # chain = prompt | model | parser
# # result = chain.invoke({'text':docs[0].page_content})
# # print(result)
# ```

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### Directory Loader

# %% [markdown]
# - Directory loader is a loader we can use to load multiple documents from a directory
# - Like we have a folder with 100s of pdfs, we can use directory loader to load data from that folder

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ```
# from langchain_community.document_loaders import PyPDFLoader, DirectoryLoader
#
# loader = DirectoryLoader(
#     path=r"D:\AgenticAI\4_Document_loaders",
#     glob=".pdf",         #all pdf files
#     loader_cls = PyPDFLoader
# )
#
#
# docs = loader.load()
# print(docs.metadata)
#
# ```

# %% [markdown]
# ##### Lazy Loading

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ```
# from langchain_community.document_loaders import PyPDFLoader, DirectoryLoader
#
# loader = DirectoryLoader(
#     path=r"D:\AgenticAI\4_Document_loaders",
#     glob=".pdf",         #all pdf files
#     loader_cls = PyPDFLoader
# )
#
#
# # docs = loader.load()
# docs = loader.lazy_load()
# print(docs.metadata)
#
# ```

# %% [markdown]
# ##### WebBaseLoader

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### Proect Idea: A Browser Plugin which gives informtion about the webpage as soon as open the page and Extract

# %% [markdown]
# ##### CSV Loader

# %% [markdown]
# - Its a document loader used to load_csv files into LangChain document objects - one per row by default

# %% [markdown]
# ```
# from langchain_community.document_loaders import CSVLoader
#
# loader = CSVLoader(file_path=r"D:\AgenticAI\4_Document_loaders\Social_Network_Ads.csv")
# docs = loader.load()
#
# print(len(docs))
# ```

# %% [markdown]
# - We can use lazy_loading if its a big csv

# %% [markdown]
# ##### LangChain Document Loader Complete list

# %% [markdown]
# - https://docs.langchain.com/oss/python/integrations/document_loaders
# - We can also create our own custom data loader

# %% [markdown]
# #### 2. Text Splitters

# %% [markdown]
# - Lets say we have a pdf with millions of pages and we have to perform some operation
# - We can split them into smaller chunks and perform the operations on each chunk
# - This process is text splitting and Text splitters does that for us
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ###### **Importance**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### 1. Length Based Text splitting

# %% [markdown]
# - create chunks on the basis of character length like 100 so it will split document into chunks of 100 where each chunk contains 100 character
# - this doesnt consider context
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ```
# from langchain_text_splitters import CharacterTextSplitter
# from langchain_community.document_loaders import PyPDFLoader
#
# # text = """
# #     Lorem ipsum dolor sit amet, consectetuer adipiscing elit. Aenean commodo ligula eget dolor. Aenean massa. Cum sociis natoque penatibus et magnis dis parturient montes, nascetur ridiculus mus. Donec quam felis, ultricies nec, pellentesque eu, pretium quis, sem. Nulla consequat massa quis enim. Donec pede justo, fringilla vel, aliquet nec, vulputate eget, arcu. In enim justo, rhoncus ut, imperdiet a, venenatis vitae, justo. Nullam dictum felis eu pede mollis pretium. Integer tincidunt. Cras dapibus. Vivamus elementum semper nisi. Aenean vulputate eleifend tellus. Aenean leo ligula, porttitor eu, consequat vitae, eleifend ac, enim. Aliquam lorem ante, dapibus in, viverra quis, feugiat a, tellus. Phasellus viverra nulla ut metus varius laoreet. Quisque rutrum. Aenean imperdiet. Etiam ultricies nisi vel augue. Curabitur ullamcorper ultricies nisi. Nam eget dui. Etiam rhoncus. Maecenas tempus, tellus eget condimentum rhoncus, sem quam semper libero, sit amet adipiscing sem neque sed ipsum. Nam quam nunc, blandit vel, luctus pulvinar, hendrerit id, lorem. Maecenas nec odio et ante tincidunt tempus. Donec vitae sapien ut libero venenatis faucibus. Nullam quis ante. Etiam sit amet orci eget eros faucibus tincidunt. Duis leo. Sed fringilla mauris sit amet nibh. Donec sodales sagittis magna. Sed consequat, leo eget bibendum sodales, augue velit cursus nunc,
# # """
#
# loader = PyPDFLoader(r"D:\AgenticAI\4_Document_loaders\dl-curriculum.pdf")
# docs = loader.load()
#
# splitter = CharacterTextSplitter(
#     chunk_size = 100,
#     chunk_overlap = 0,
#     separator = ''
# )
#
# # result = splitter.split_text(text)
# result = splitter.split_documents(docs)     #each chunk will be a document object
# print(result[0])
# ```

# %% [markdown]
# **chunk overlap**
# - used as buffer to avoid abruptly cutting a word like at 100 charach word may cut at "curric" vs "curriculum"

# %% [markdown]
# ##### 2. Text-structure based

# %% [markdown]
# - It considers text inherently follows a structure like paragraphs, sentence, words
# - It uses this heriarchy of structuring
# - **recursive character text splitting**
#
# ![image.png](attachment:image.png)
#
# - splitter will 1st make chunks on the basis of paragraphs then sentences then words then finally characters
# - All the time it will try to avoid cutting the word abruptly

# %% [markdown]
# **example:**
#
# ![image.png](attachment:image.png)
#
# - initial chunk size is 10
# - it will 1st split on the basis of paragraphs
#
# ![image-2.png](attachment:image-2.png)
#
# - since both are still voilating allowed chunk size which is 10 so it will further split on the basis of lines
#
# ![image-3.png](attachment:image-3.png)
#
# - again voilating max allowed chunk size so further split into words
# - finally it will split like this
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)
#
# ![image-7.png](attachment:image-7.png)

# %% [markdown]
# ```
# from langchain_text_splitters import RecursiveCharacterTextSplitter
# from langchain_community.document_loaders import PyPDFLoader
#
# text = """
#     Lorem ipsum dolor sit amet, consectetuer adipiscing elit. Aenean commodo ligula eget dolor. Aenean massa. Cum sociis natoque penatibus et magnis dis parturient montes, nascetur ridiculus mus. Donec quam felis, ultricies nec, pellentesque eu, pretium quis, sem. Nulla consequat massa quis enim. Donec pede justo, fringilla vel, aliquet nec, vulputate eget, arcu. In enim justo, rhoncus ut, imperdiet a, venenatis vitae, justo. Nullam dictum felis eu pede mollis pretium. Integer tincidunt. Cras dapibus. Vivamus elementum semper nisi. Aenean vulputate eleifend tellus. Aenean leo ligula, porttitor eu, consequat vitae, eleifend ac, enim. Aliquam lorem ante, dapibus in, viverra quis, feugiat a, tellus. Phasellus viverra nulla ut metus varius laoreet. Quisque rutrum. Aenean imperdiet. Etiam ultricies nisi vel augue. Curabitur ullamcorper ultricies nisi. Nam eget dui. Etiam rhoncus. Maecenas tempus, tellus eget condimentum rhoncus, sem quam semper libero, sit amet adipiscing sem neque sed ipsum. Nam quam nunc, blandit vel, luctus pulvinar, hendrerit id, lorem. Maecenas nec odio et ante tincidunt tempus. Donec vitae sapien ut libero venenatis faucibus. Nullam quis ante. Etiam sit amet orci eget eros faucibus tincidunt. Duis leo. Sed fringilla mauris sit amet nibh. Donec sodales sagittis magna. Sed consequat, leo eget bibendum sodales, augue velit cursus nunc,
# """
#
# loader = PyPDFLoader(r"D:\AgenticAI\4_Document_loaders\dl-curriculum.pdf")
# docs = loader.load()
#
# splitter = RecursiveCharacterTextSplitter(
#     chunk_size = 300,
#     chunk_overlap = 0,
# )
#
# result = splitter.split_text(text)
# chunks = splitter.split_documents(docs)     #each chunk will be a document object
# print(len(chunks))
# print(chunks)
#
# print(len(result))
# ```

# %% [markdown]
# ##### 3. Document-structure based

# %% [markdown]
# - earlier we have used text strcutre to split like para, sentence, line, words but what if document is organized in different structure
#
# ![image.png](attachment:image.png)
#
# - we are still using RCTS technique - only difference is seperators we use are different like for python code document
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ##### 4. Semantic Meaning Based

# %% [markdown]
# - In some cases recursive text splitter will fail - meaning quality will not be good bcoz it will create 2 chunks
# - Ideally it should create 3 chunks and then split them further to maintain the semantic meaning
#
# ![image.png](attachment:image.png)
#
# - We split into lines and generate embeddings -- and wherever similarity changes -- we split
# - We have to define a threshold at how much similarity changes we split --> like if similarity difference is more then 1 then we will split
#
#
# ```
# from langchain_experimental.text_splitter import SemanticChunker
# from langchain_openai.embeddings import OpenAIEmbeddings
# from dotenv import load_dotenv
#
# load_dotenv()
#
# text_splitter = SemanticChunker(
#     OpenAIEmbeddings(), breakpoint_threshold_type="standard_deviation",
#     breakpoint_threshold_amount=3
# )
#
# sample = """
# Farmers were working hard in the fields, preparing the soil and planting seeds for the next season. The sun was bright, and the air smelled of earth and fresh grass. The Indian Premier League (IPL) is the biggest cricket league in the world. People all over the world watch the matches and cheer for their favourite teams.
#
#
# Terrorism is a big danger to peace and safety. It causes harm to people and creates fear in cities and villages. When such attacks happen, they leave behind pain and sadness. To fight terrorism, we need strong laws, alert security forces, and support from people who care about peace and safety.
# """
#
# docs = text_splitter.create_documents([sample])
# print(len(docs))
# print(docs)
#
#
# ```

# %% [markdown]
# #### 3. Vector Stores

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - **Why do we need Vector Stores**
#
# - lets say we want to build a website where we want to list all movies like IMDb so that whenever user searches for a movie and clicks - It will give all details about the movie
# - how to build this kind of website?
#     1. dbs with all movie data
#     2. we can build a backend which pulls data from dbs & display results in frontend
# - we want to add movie reccomender system also in the website so that we can also reccomend movies similar to what user searched which will increase user engagement and we can show more ads and earn more money
# - to build movie reccomender system: we can do **keyword matching** like 2 movies m1 & m2 with same actor director & jonner then it means these 2 are very similar so we can reccomend m2
# - there is a flaw in this type of system: like if i searched for "my name is khan" and now its suggesting "kabhi alvida na kehna" which although are similar based on keywords but actually opposite and movies like **taare zameen par** & **a beautiful mind** which are actually similar but our system can not suggest them together bcoz keywords doesnt match ---> this is a complete turn off !!
# - How to improve then?? --> Compare movie plot instead !!
# - so now i have to build a system which compares plot of 2 movies and generate similarity score --> higher similarity score means more similar those 2 movies are
# - **Nueral Networks/Embeddings** solves this --> we give text as input and it will returns **embedding vector** as output
# - now we have embedding vectors of all movie plots, finding similarity b/w these vectors is easy
# - we can find similarity and reccomend the closest vector or 2 movies which has highest similarity
# - Problems:
#     1. generating embedding vectors of millions of movies
#     2. storing these vectors
#     3. perform semantic search (cosine similarity) b/w millions of movies vectors
#
#     - **Vector Stores** helps in all 3 problems
#
#
# - **Whats Vector Stores?**
#     - vector store is a system designed to store and retrieve data represented as numerical vector
#
#     ![image.png](attachment:image.png)
#
# - **Difference b/w vector store and vector database**
#     - vector store refers to a lightweight library that focuses on storing vectors (embeddings) and performing similarity search
#     - It may not include traditional dbs features like transactions, rich query, languages, concurreny, authentication etc
#     - when we add those features then in vector store then its called **Vector Dbs**
#
#     ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ##### Vector stores in Langchain

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### Chroma vector store

# %% [markdown]
# https://www.youtube.com/watch?v=k13WK0bxQP0 --> done
