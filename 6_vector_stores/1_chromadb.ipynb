# %%
import sys
venv_python = r"D:\AgenticAI\venv\Scripts\python.exe"

from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import Chroma

# %%
from langchain_core.documents import Document

# Create LangChain documents for IPL players

doc1 = Document(
        page_content="Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.",
        metadata={"team": "Royal Challengers Bangalore"}
    )
doc2 = Document(
        page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
        metadata={"team": "Mumbai Indians"}
    )
doc3 = Document(
        page_content="MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.",
        metadata={"team": "Chennai Super Kings"}
    )
doc4 = Document(
        page_content="Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.",
        metadata={"team": "Mumbai Indians"}
    )
doc5 = Document(
        page_content="Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.",
        metadata={"team": "Chennai Super Kings"}
    )

# %%
docs = [doc1, doc2, doc3, doc4, doc5]

# %%
import sys
venv_python = r"D:\AgenticAI\venv\Scripts\python.exe"

# Install chromadb
# !{venv_python} -m pip install chromadb
# Out:
# Collecting chromadb
# [notice] A new release of pip is available: 23.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
#   Downloading chromadb-1.5.9-cp39-abi3-win_amd64.whl (23.5 MB)
#      ---------------------------------------- 0.0/23.5 MB ? eta -:--:--
#      ---------------------------------------- 0.1/23.5 MB 3.2 MB/s eta 0:00:08
#      ---------------------------------------- 0.1/23.5 MB 1.3 MB/s eta 0:00:18
#      ---------------------------------------- 0.1/23.5 MB 1.1 MB/s eta 0:00:22
#      ---------------------------------------- 0.2/23.5 MB 1.1 MB/s eta 0:00:21
#      ---------------------------------------- 0.2/23.5 MB 1.0 MB/s eta 0:00:23
#       --------------------------------------- 0.3/23.5 MB 1.2 MB/s eta 0:00:21
#       --------------------------------------- 0.4/23.5 MB 1.1 MB/s eta 0:00:21
#       --------------------------------------- 0.5/23.5 MB 1.3 MB/s eta 0:00:19
#       --------------------------------------- 0.5/23.5 MB 1.3 MB/s eta 0:00:19
#       --------------------------------------- 0.6/23.5 MB 1.3 MB/s eta 0:00:19
#      - -------------------------------------- 0.7/23.5 MB 1.3 MB/s eta 0:00:18
#      - -------------------------------------- 0.7/23.5 MB 1.3 MB/s eta 0:00:17
#      - -------------------------------------- 0.9/23.5 MB 1.4 MB/s eta 0:00:16
#      - -------------------------------------- 1.0/23.5 MB 1.5 MB/s eta 0:00:16
#      - -------------------------------------- 1.1/23.5 MB 1.5 MB/s eta 0:00:15
#      -- ------------------------------------- 1.3/23.5 MB 1.5 MB/s eta 0:00:15
#      -- ------------------------------------- 1.4/23.5 MB 1.5 MB/s eta 0:00:15
#      -- ------------------------------------- 1.5/23.5 MB 1.5 MB/s eta 0:00:15
#      -- ------------------------------------- 1.6/23.5 MB 1.5 MB/s eta 0:00:15
#      -- ------------------------------------- 1.6/23.5 MB 1.5 MB/s eta 0:00:15
#      -- ------------------------------------- 1.7/23.5 MB 1.5 MB/s eta 0:00:15
#      -- ------------------------------------- 1.8/23.5 MB 1.5 MB/s eta 0:00:15
#      --- ------------------------------------ 1.8/23.5 MB 1.5 MB/s eta 0:00:15
#      --- ------------------------------------ 1.9/23.5 MB 1.5 MB/s eta 0:00:15
#      --- ------------------------------------ 1.9/23.5 MB 1.5 MB/s eta 0:00:15
#      --- ------------------------------------ 2.0/23.5 MB 1.5 MB/s eta 0:00:15
#      --- ------------------------------------ 2.1/23.5 MB 1.5 MB/s eta 0:00:15
#      --- ------------------------------------ 2.2/23.5 MB 1.5 MB/s eta 0:00:15
#      --- ------------------------------------ 2.3/23.5 MB 1.5 MB/s eta 0:00:15
#      --- ------------------------------------ 2.3/23.5 MB 1.5 MB/s eta 0:00:15
#      ---- ----------------------------------- 2.4/23.5 MB 1.5 MB/s eta 0:00:14
#      ---- ----------------------------------- 2.5/23.5 MB 1.6 MB/s eta 0:00:14
#      ---- ----------------------------------- 2.6/23.5 MB 1.6 MB/s eta 0:00:14
#      ---- ----------------------------------- 2.7/23.5 MB 1.5 MB/s eta 0:00:14
#      ---- ----------------------------------- 2.8/23.5 MB 1.6 MB/s eta 0:00:14
#      ---- ----------------------------------- 2.9/23.5 MB 1.6 MB/s eta 0:00:13
#      ----- ---------------------------------- 3.0/23.5 MB 1.6 MB/s eta 0:00:13
#      ----- ---------------------------------- 3.2/23.5 MB 1.7 MB/s eta 0:00:13
#      ----- ---------------------------------- 3.3/23.5 MB 1.7 MB/s eta 0:00:13
#      ----- ---------------------------------- 3.5/23.5 MB 1.7 MB/s eta 0:00:12
#      ------ --------------------------------- 3.8/23.5 MB 1.7 MB/s eta 0:00:12
#      ------ --------------------------------- 4.0/23.5 MB 1.8 MB/s eta 0:00:12
#      ------ --------------------------------- 4.1/23.5 MB 1.8 MB/s eta 0:00:11
#      ------- -------------------------------- 4.3/23.5 MB 1.8 MB/s eta 0:00:11
#      ------- -------------------------------- 4.4/23.5 MB 1.8 MB/s eta 0:00:11
#      ------- -------------------------------- 4.6/23.5 MB 1.9 MB/s eta 0:00:10
#      -------- ------------------------------- 4.7/23.5 MB 1.9 MB/s eta 0:00:10
#      -------- ------------------------------- 4.9/23.5 MB 2.0 MB/s eta 0:00:10
#      -------- ------------------------------- 5.1/23.5 MB 2.0 MB/s eta 0:00:10
#      --------- ------------------------------ 5.3/23.5 MB 2.0 MB/s eta 0:00:10
#      --------- ------------------------------ 5.4/23.5 MB 2.0 MB/s eta 0:00:09
#      --------- ------------------------------ 5.7/23.5 MB 2.1 MB/s eta 0:00:09
#      --------- ------------------------------ 5.8/23.5 MB 2.1 MB/s eta 0:00:09
#      ---------- ----------------------------- 6.0/23.5 MB 2.1 MB/s eta 0:00:09
#      ---------- ----------------------------- 6.1/23.5 MB 2.1 MB/s eta 0:00:09
#      ---------- ----------------------------- 6.3/23.5 MB 2.1 MB/s eta 0:00:09
#      ---------- ----------------------------- 6.5/23.5 MB 2.2 MB/s eta 0:00:08
#      ----------- ---------------------------- 6.6/23.5 MB 2.2 MB/s eta 0:00:08
#      ----------- ---------------------------- 6.8/23.5 MB 2.2 MB/s eta 0:00:08
#      ----------- ---------------------------- 6.9/23.5 MB 2.2 MB/s eta 0:00:08
#      ----------- ---------------------------- 7.0/23.5 MB 2.2 MB/s eta 0:00:08
#      ------------ --------------------------- 7.4/23.5 MB 2.3 MB/s eta 0:00:08
#      ------------- -------------------------- 7.7/23.5 MB 2.3 MB/s eta 0:00:07
#      ------------- -------------------------- 8.0/23.5 MB 2.3 MB/s eta 0:00:07
#      ------------- -------------------------- 8.2/23.5 MB 2.4 MB/s eta 0:00:07
#      -------------- ------------------------- 8.3/23.5 MB 2.4 MB/s eta 0:00:07
#      -------------- ------------------------- 8.5/23.5 MB 2.4 MB/s eta 0:00:07
#      -------------- ------------------------- 8.8/23.5 MB 2.4 MB/s eta 0:00:07
#      --------------- ------------------------ 9.1/23.5 MB 2.4 MB/s eta 0:00:06
#      ---------------- ----------------------- 9.5/23.5 MB 2.4 MB/s eta 0:00:06
#      ---------------- ----------------------- 9.9/23.5 MB 2.5 MB/s eta 0:00:06
#      ----------------- ---------------------- 10.3/23.5 MB 2.5 MB/s eta 0:00:06
#      ------------------ --------------------- 10.6/23.5 MB 2.7 MB/s eta 0:00:05
#      ------------------ --------------------- 11.0/23.5 MB 2.8 MB/s eta 0:00:05
#      ------------------- -------------------- 11.4/23.5 MB 2.8 MB/s eta 0:00:05
#      ------------------- -------------------- 11.6/23.5 MB 2.9 MB/s eta 0:00:05
#      -------------------- ------------------- 11.8/23.5 MB 3.0 MB/s eta 0:00:04
#      -------------------- ------------------- 12.0/23.5 MB 3.1 MB/s eta 0:00:04
#      -------------------- ------------------- 12.2/23.5 MB 3.2 MB/s eta 0:00:04
#      --------------------- ------------------ 12.4/23.5 MB 3.2 MB/s eta 0:00:04
#      --------------------- ------------------ 12.6/23.5 MB 3.3 MB/s eta 0:00:04
#      --------------------- ------------------ 12.7/23.5 MB 3.3 MB/s eta 0:00:04
#      ---------------------- ----------------- 13.0/23.5 MB 3.4 MB/s eta 0:00:04
#      ---------------------- ----------------- 13.1/23.5 MB 3.4 MB/s eta 0:00:04
#      ---------------------- ----------------- 13.3/23.5 MB 3.4 MB/s eta 0:00:04
#      ---------------------- ----------------- 13.4/23.5 MB 3.4 MB/s eta 0:00:03
#      ---------------------- ----------------- 13.5/23.5 MB 3.4 MB/s eta 0:00:03
#      ----------------------- ---------------- 13.8/23.5 MB 3.5 MB/s eta 0:00:03
#      ----------------------- ---------------- 13.9/23.5 MB 3.5 MB/s eta 0:00:03
#      ----------------------- ---------------- 14.1/23.5 MB 3.5 MB/s eta 0:00:03
#      ------------------------ --------------- 14.2/23.5 MB 3.5 MB/s eta 0:00:03
#      ------------------------ --------------- 14.4/23.5 MB 3.5 MB/s eta 0:00:03
#      ------------------------ --------------- 14.6/23.5 MB 3.6 MB/s eta 0:00:03
#      ------------------------- -------------- 14.8/23.5 MB 3.5 MB/s eta 0:00:03
#      ------------------------- -------------- 15.0/23.5 MB 3.5 MB/s eta 0:00:03
#      ------------------------- -------------- 15.2/23.5 MB 3.5 MB/s eta 0:00:03
#      -------------------------- ------------- 15.3/23.5 MB 3.5 MB/s eta 0:00:03
#      -------------------------- ------------- 15.5/23.5 MB 3.6 MB/s eta 0:00:03
#      -------------------------- ------------- 15.7/23.5 MB 3.6 MB/s eta 0:00:03
#      --------------------------- ------------ 15.9/23.5 MB 3.6 MB/s eta 0:00:03
#      --------------------------- ------------ 16.1/23.5 MB 3.6 MB/s eta 0:00:03
#      --------------------------- ------------ 16.3/23.5 MB 3.6 MB/s eta 0:00:03
#      ---------------------------- ----------- 16.5/23.5 MB 3.6 MB/s eta 0:00:02
#      ----------------------------- ---------- 17.1/23.5 MB 3.7 MB/s eta 0:00:02
#      ----------------------------- ---------- 17.4/23.5 MB 3.7 MB/s eta 0:00:02
#      ------------------------------ --------- 17.8/23.5 MB 3.7 MB/s eta 0:00:02
#      ------------------------------ --------- 18.2/23.5 MB 3.7 MB/s eta 0:00:02
#      ------------------------------- -------- 18.5/23.5 MB 3.7 MB/s eta 0:00:02
#      -------------------------------- ------- 18.9/23.5 MB 3.8 MB/s eta 0:00:02
#      -------------------------------- ------- 19.2/23.5 MB 3.9 MB/s eta 0:00:02
#      -------------------------------- ------- 19.4/23.5 MB 3.9 MB/s eta 0:00:02
#      --------------------------------- ------ 19.7/23.5 MB 3.9 MB/s eta 0:00:01
#      --------------------------------- ------ 19.9/23.5 MB 3.9 MB/s eta 0:00:01
#      ---------------------------------- ----- 20.0/23.5 MB 3.9 MB/s eta 0:00:01
#      ---------------------------------- ----- 20.3/23.5 MB 3.9 MB/s eta 0:00:01
#      ---------------------------------- ----- 20.5/23.5 MB 4.0 MB/s eta 0:00:01
#      ---------------------------------- ----- 20.6/23.5 MB 3.9 MB/s eta 0:00:01
#      ----------------------------------- ---- 20.8/23.5 MB 3.9 MB/s eta 0:00:01
#      ----------------------------------- ---- 21.1/23.5 MB 3.9 MB/s eta 0:00:01
#      ------------------------------------ --- 21.3/23.5 MB 4.0 MB/s eta 0:00:01
#      ------------------------------------ --- 21.6/23.5 MB 4.0 MB/s eta 0:00:01
#      ------------------------------------- -- 21.9/23.5 MB 4.1 MB/s eta 0:00:01
#      ------------------------------------- -- 22.1/23.5 MB 4.1 MB/s eta 0:00:01
#      ------------------------------------- -- 22.3/23.5 MB 4.1 MB/s eta 0:00:01
#      -------------------------------------- - 22.6/23.5 MB 4.1 MB/s eta 0:00:01
#      -------------------------------------- - 22.8/23.5 MB 4.1 MB/s eta 0:00:01
#      ---------------------------------------  23.1/23.5 MB 4.1 MB/s eta 0:00:01
#      ---------------------------------------  23.3/23.5 MB 4.1 MB/s eta 0:00:01
#      ---------------------------------------  23.5/23.5 MB 4.2 MB/s eta 0:00:01
#      ---------------------------------------  23.5/23.5 MB 4.2 MB/s eta 0:00:01
#      ---------------------------------------  23.5/23.5 MB 4.2 MB/s eta 0:00:01
#      ---------------------------------------  23.5/23.5 MB 4.2 MB/s eta 0:00:01
#      ---------------------------------------- 23.5/23.5 MB 3.8 MB/s eta 0:00:00
# Collecting kubernetes>=28.1.0
#   Downloading kubernetes-35.0.0-py2.py3-none-any.whl (2.0 MB)
#      ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#      --- ------------------------------------ 0.2/2.0 MB 4.5 MB/s eta 0:00:01
#      ------ --------------------------------- 0.3/2.0 MB 3.9 MB/s eta 0:00:01
#      --------- ------------------------------ 0.5/2.0 MB 3.3 MB/s eta 0:00:01
#      -------------- ------------------------- 0.7/2.0 MB 3.8 MB/s eta 0:00:01
#      ------------------- -------------------- 1.0/2.0 MB 4.1 MB/s eta 0:00:01
#      ----------------------- ---------------- 1.2/2.0 MB 4.2 MB/s eta 0:00:01
#      ----------------------------- ---------- 1.5/2.0 MB 4.3 MB/s eta 0:00:01
#      ----------------------------------- ---- 1.8/2.0 MB 4.6 MB/s eta 0:00:01
#      ---------------------------------------  2.0/2.0 MB 4.6 MB/s eta 0:00:01
#      ---------------------------------------- 2.0/2.0 MB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: pydantic-settings>=2.0 in d:\agenticai\venv\lib\site-packages (from chromadb) (2.14.1)
# Requirement already satisfied: grpcio>=1.58.0 in d:\agenticai\venv\lib\site-packages (from chromadb) (1.80.0)
# Requirement already satisfied: httpx>=0.27.0 in d:\agenticai\venv\lib\site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: numpy>=1.22.5 in d:\agenticai\venv\lib\site-packages (from chromadb) (2.2.6)
# Requirement already satisfied: orjson>=3.9.12 in d:\agenticai\venv\lib\site-packages (from chromadb) (3.11.9)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.42.0-py3-none-any.whl (19 kB)
# Collecting opentelemetry-api>=1.2.0
#   Downloading opentelemetry_api-1.42.0-py3-none-any.whl (61 kB)
#      ---------------------------------------- 0.0/61.3 kB ? eta -:--:--
#      ---------------------------------------- 61.3/61.3 kB 3.4 MB/s eta 0:00:00
# Collecting pypika>=0.48.9
#   Downloading pypika-0.51.1-py2.py3-none-any.whl (60 kB)
#      ---------------------------------------- 0.0/60.6 kB ? eta -:--:--
#      ---------------------------------------- 60.6/60.6 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.65.0 in d:\agenticai\venv\lib\site-packages (from chromadb) (4.67.3)
# Collecting pybase64>=1.4.1
#   Downloading pybase64-1.4.3-cp310-cp310-win_amd64.whl (35 kB)
# Collecting bcrypt>=4.0.1
#   Using cached bcrypt-5.0.0-cp39-abi3-win_amd64.whl (150 kB)
# Collecting onnxruntime>=1.14.1
#   Downloading onnxruntime-1.23.2-cp310-cp310-win_amd64.whl (13.5 MB)
#      ---------------------------------------- 0.0/13.5 MB ? eta -:--:--
#      - -------------------------------------- 0.4/13.5 MB 8.1 MB/s eta 0:00:02
#      - -------------------------------------- 0.6/13.5 MB 7.1 MB/s eta 0:00:02
#      -- ------------------------------------- 1.0/13.5 MB 6.8 MB/s eta 0:00:02
#      --- ------------------------------------ 1.2/13.5 MB 6.3 MB/s eta 0:00:02
#      ---- ----------------------------------- 1.4/13.5 MB 5.6 MB/s eta 0:00:03
#      ---- ----------------------------------- 1.6/13.5 MB 5.4 MB/s eta 0:00:03
#      ----- ---------------------------------- 1.8/13.5 MB 5.3 MB/s eta 0:00:03
#      ------ --------------------------------- 2.1/13.5 MB 5.3 MB/s eta 0:00:03
#      ------- -------------------------------- 2.4/13.5 MB 5.4 MB/s eta 0:00:03
#      ------- -------------------------------- 2.6/13.5 MB 5.4 MB/s eta 0:00:03
#      -------- ------------------------------- 2.8/13.5 MB 5.2 MB/s eta 0:00:03
#      --------- ------------------------------ 3.2/13.5 MB 5.5 MB/s eta 0:00:02
#      ---------- ----------------------------- 3.4/13.5 MB 5.5 MB/s eta 0:00:02
#      ----------- ---------------------------- 3.8/13.5 MB 5.6 MB/s eta 0:00:02
#      ----------- ---------------------------- 3.9/13.5 MB 5.4 MB/s eta 0:00:02
#      ------------ --------------------------- 4.2/13.5 MB 5.5 MB/s eta 0:00:02
#      ------------- -------------------------- 4.6/13.5 MB 5.6 MB/s eta 0:00:02
#      --------------- ------------------------ 5.2/13.5 MB 5.8 MB/s eta 0:00:02
#      ---------------- ----------------------- 5.4/13.5 MB 5.8 MB/s eta 0:00:02
#      ----------------- ---------------------- 5.8/13.5 MB 5.9 MB/s eta 0:00:02
#      ------------------ --------------------- 6.1/13.5 MB 5.9 MB/s eta 0:00:02
#      ------------------- -------------------- 6.5/13.5 MB 6.0 MB/s eta 0:00:02
#      ------------------- -------------------- 6.7/13.5 MB 6.0 MB/s eta 0:00:02
#      --------------------- ------------------ 7.1/13.5 MB 6.1 MB/s eta 0:00:02
#      --------------------- ------------------ 7.4/13.5 MB 6.0 MB/s eta 0:00:02
#      ---------------------- ----------------- 7.6/13.5 MB 5.9 MB/s eta 0:00:01
#      ---------------------- ----------------- 7.7/13.5 MB 6.0 MB/s eta 0:00:01
#      ------------------------ --------------- 8.1/13.5 MB 5.9 MB/s eta 0:00:01
#      ------------------------ --------------- 8.3/13.5 MB 5.8 MB/s eta 0:00:01
#      ------------------------- -------------- 8.5/13.5 MB 5.8 MB/s eta 0:00:01
#      ------------------------- -------------- 8.7/13.5 MB 5.8 MB/s eta 0:00:01
#      -------------------------- ------------- 9.0/13.5 MB 5.7 MB/s eta 0:00:01
#      --------------------------- ------------ 9.2/13.5 MB 5.8 MB/s eta 0:00:01
#      ---------------------------- ----------- 9.5/13.5 MB 5.8 MB/s eta 0:00:01
#      ----------------------------- ---------- 9.8/13.5 MB 5.7 MB/s eta 0:00:01
#      ----------------------------- ---------- 10.1/13.5 MB 5.7 MB/s eta 0:00:01
#      ------------------------------- -------- 10.5/13.5 MB 5.8 MB/s eta 0:00:01
#      -------------------------------- ------- 10.9/13.5 MB 5.9 MB/s eta 0:00:01
#      --------------------------------- ------ 11.2/13.5 MB 5.9 MB/s eta 0:00:01
#      ---------------------------------- ----- 11.5/13.5 MB 6.0 MB/s eta 0:00:01
#      ----------------------------------- ---- 11.9/13.5 MB 6.1 MB/s eta 0:00:01
#      ------------------------------------- -- 12.7/13.5 MB 6.2 MB/s eta 0:00:01
#      ---------------------------------------  13.3/13.5 MB 6.2 MB/s eta 0:00:01
#      ---------------------------------------  13.5/13.5 MB 6.1 MB/s eta 0:00:01
#      ---------------------------------------  13.5/13.5 MB 6.1 MB/s eta 0:00:01
#      ---------------------------------------- 13.5/13.5 MB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: typer>=0.9.0 in d:\agenticai\venv\lib\site-packages (from chromadb) (0.25.1)
# Requirement already satisfied: pyyaml>=6.0.0 in d:\agenticai\venv\lib\site-packages (from chromadb) (6.0.3)
# Collecting overrides>=7.3.1
#   Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Collecting importlib-resources
#   Downloading importlib_resources-7.1.0-py3-none-any.whl (37 kB)
# Requirement already satisfied: tenacity>=8.2.3 in d:\agenticai\venv\lib\site-packages (from chromadb) (9.1.4)
# Collecting opentelemetry-sdk>=1.2.0
#   Downloading opentelemetry_sdk-1.42.0-py3-none-any.whl (170 kB)
#      ---------------------------------------- 0.0/170.9 kB ? eta -:--:--
#      -------------------------------------- 170.9/170.9 kB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: jsonschema>=4.19.0 in d:\agenticai\venv\lib\site-packages (from chromadb) (4.26.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in d:\agenticai\venv\lib\site-packages (from chromadb) (4.15.0)
# Requirement already satisfied: tokenizers>=0.13.2 in d:\agenticai\venv\lib\site-packages (from chromadb) (0.22.2)
# Collecting build>=1.0.3
#   Downloading build-1.5.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in d:\agenticai\venv\lib\site-packages (from chromadb) (0.46.0)
# Collecting mmh3>=4.0.1
#   Downloading mmh3-5.2.1-cp310-cp310-win_amd64.whl (41 kB)
#      ---------------------------------------- 0.0/41.5 kB ? eta -:--:--
#      ---------------------------------------- 41.5/41.5 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: rich>=10.11.0 in d:\agenticai\venv\lib\site-packages (from chromadb) (15.0.0)
# Requirement already satisfied: pydantic>=2.0 in d:\agenticai\venv\lib\site-packages (from chromadb) (2.13.4)
# Requirement already satisfied: colorama in d:\agenticai\venv\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Collecting tomli>=1.1.0
#   Using cached tomli-2.4.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: packaging>=24.0 in d:\agenticai\venv\lib\site-packages (from build>=1.0.3->chromadb) (26.2)
# Collecting pyproject_hooks
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: httpcore==1.* in d:\agenticai\venv\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: certifi in d:\agenticai\venv\lib\site-packages (from httpx>=0.27.0->chromadb) (2026.4.22)
# Requirement already satisfied: anyio in d:\agenticai\venv\lib\site-packages (from httpx>=0.27.0->chromadb) (4.13.0)
# Requirement already satisfied: idna in d:\agenticai\venv\lib\site-packages (from httpx>=0.27.0->chromadb) (3.13)
# Requirement already satisfied: h11>=0.16 in d:\agenticai\venv\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: referencing>=0.28.4 in d:\agenticai\venv\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in d:\agenticai\venv\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.0)
# Requirement already satisfied: attrs>=22.2.0 in d:\agenticai\venv\lib\site-packages (from jsonschema>=4.19.0->chromadb) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\agenticai\venv\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in d:\agenticai\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.7.0)
# Collecting websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0
#   Downloading websocket_client-1.9.0-py3-none-any.whl (82 kB)
#      ---------------------------------------- 0.0/82.6 kB ? eta -:--:--
#      ---------------------------------------  81.9/82.6 kB 2.3 MB/s eta 0:00:01
#      ---------------------------------------- 82.6/82.6 kB 1.5 MB/s eta 0:00:00
# Collecting requests-oauthlib
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Collecting durationpy>=0.7
#   Downloading durationpy-0.10-py3-none-any.whl (3.9 kB)
# Requirement already satisfied: python-dateutil>=2.5.3 in d:\agenticai\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: six>=1.9.0 in d:\agenticai\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: requests in d:\agenticai\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.33.1)
# Requirement already satisfied: protobuf in d:\agenticai\venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.6)
# Collecting coloredlogs
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ---------------------------------------- 0.0/46.0 kB ? eta -:--:--
#      ---------------------------------------- 46.0/46.0 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: sympy in d:\agenticai\venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Collecting flatbuffers
#   Downloading flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Collecting opentelemetry-proto==1.42.0
#   Downloading opentelemetry_proto-1.42.0-py3-none-any.whl (71 kB)
#      ---------------------------------------- 0.0/71.8 kB ? eta -:--:--
#      ---------------------------------------- 71.8/71.8 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: googleapis-common-protos~=1.57 in d:\agenticai\venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.75.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.42.0
#   Downloading opentelemetry_exporter_otlp_proto_common-1.42.0-py3-none-any.whl (17 kB)
# Collecting opentelemetry-semantic-conventions==0.63b0
#   Downloading opentelemetry_semantic_conventions-0.63b0-py3-none-any.whl (203 kB)
#      ---------------------------------------- 0.0/203.7 kB ? eta -:--:--
#      ------------------------------------ - 194.6/203.7 kB 5.8 MB/s eta 0:00:01
#      -------------------------------------- 203.7/203.7 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.6.0 in d:\agenticai\venv\lib\site-packages (from pydantic>=2.0->chromadb) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\agenticai\venv\lib\site-packages (from pydantic>=2.0->chromadb) (0.4.2)
# Requirement already satisfied: pydantic-core==2.46.4 in d:\agenticai\venv\lib\site-packages (from pydantic>=2.0->chromadb) (2.46.4)
# Requirement already satisfied: python-dotenv>=0.21.0 in d:\agenticai\venv\lib\site-packages (from pydantic-settings>=2.0->chromadb) (1.2.2)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\agenticai\venv\lib\site-packages (from rich>=10.11.0->chromadb) (2.20.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\agenticai\venv\lib\site-packages (from rich>=10.11.0->chromadb) (4.2.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in d:\agenticai\venv\lib\site-packages (from tokenizers>=0.13.2->chromadb) (1.14.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in d:\agenticai\venv\lib\site-packages (from typer>=0.9.0->chromadb) (0.0.4)
# Requirement already satisfied: shellingham>=1.3.0 in d:\agenticai\venv\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: click>=8.2.1 in d:\agenticai\venv\lib\site-packages (from typer>=0.9.0->chromadb) (8.3.3)
# Collecting watchfiles>=0.20
#   Downloading watchfiles-1.2.0-cp310-cp310-win_amd64.whl (290 kB)
#      ---------------------------------------- 0.0/290.1 kB ? eta -:--:--
#      -------------------------------------  286.7/290.1 kB 8.9 MB/s eta 0:00:01
#      -------------------------------------- 290.1/290.1 kB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: websockets>=10.4 in d:\agenticai\venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (16.0)
# Requirement already satisfied: httptools>=0.6.3 in d:\agenticai\venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: filelock>=3.10.0 in d:\agenticai\venv\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.29.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in d:\agenticai\venv\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.5.0)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\agenticai\venv\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2026.4.0)
# Requirement already satisfied: mdurl~=0.1 in d:\agenticai\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in d:\agenticai\venv\lib\site-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.1)
# Collecting humanfriendly>=9.1
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#      ---------------------------------------- 86.8/86.8 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\agenticai\venv\lib\site-packages (from requests->kubernetes>=28.1.0->chromadb) (3.4.7)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.3.1-py3-none-any.whl (160 kB)
#      ---------------------------------------- 0.0/160.1 kB ? eta -:--:--
#      -------------------------------------- 160.1/160.1 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\agenticai\venv\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Collecting pyreadline3
#   Downloading pyreadline3-3.5.6-py3-none-any.whl (85 kB)
#      ---------------------------------------- 0.0/85.2 kB ? eta -:--:--
#      ---------------------------------------- 85.2/85.2 kB 2.4 MB/s eta 0:00:00
# Installing collected packages: flatbuffers, durationpy, websocket-client, tomli, pyreadline3, pyproject_hooks, pypika, pybase64, overrides, opentelemetry-proto, opentelemetry-api, oauthlib, mmh3, importlib-resources, bcrypt, requests-oauthlib, opentelemetry-semantic-conventions, opentelemetry-exporter-otlp-proto-common, humanfriendly, build, watchfiles, opentelemetry-sdk, kubernetes, coloredlogs, opentelemetry-exporter-otlp-proto-grpc, onnxruntime, chromadb
# Successfully installed bcrypt-5.0.0 build-1.5.0 chromadb-1.5.9 coloredlogs-15.0.1 durationpy-0.10 flatbuffers-25.12.19 humanfriendly-10.0 importlib-resources-7.1.0 kubernetes-35.0.0 mmh3-5.2.1 oauthlib-3.3.1 onnxruntime-1.23.2 opentelemetry-api-1.42.0 opentelemetry-exporter-otlp-proto-common-1.42.0 opentelemetry-exporter-otlp-proto-grpc-1.42.0 opentelemetry-proto-1.42.0 opentelemetry-sdk-1.42.0 opentelemetry-semantic-conventions-0.63b0 overrides-7.7.0 pybase64-1.4.3 pypika-0.51.1 pyproject_hooks-1.2.0 pyreadline3-3.5.6 requests-oauthlib-2.0.0 tomli-2.4.1 watchfiles-1.2.0 websocket-client-1.9.0

# %%
vector_store = Chroma(
    embedding_function=OpenAIEmbeddings(),      #which model will perform embeddings
    persist_directory='my_chroma_db',           #locations where vector will be saved
    collection_name='sample'                    #collection name
)

# %%
#now we can use this vector store to perform different CRUD operations

# %%
# add documents --> we can add multiple docs at once - each will get asigned a unique id
vector_store.add_documents(docs)
# Out:
# ['b6f6943a-6025-49ed-aae6-ca5f1f3dabb7',
#  '5f4b7001-f768-44de-bf62-7ed42e7df763',
#  '8586e19d-dbb5-48ca-8f99-f8786e231ea0',
#  '3e1e7c74-f29d-4955-8a47-2c933089e2ea',
#  '1e90e99a-75e6-44cf-b9ea-8bad0ae61664']

# %%
# view documents
vector_store.get(include=['embeddings','documents', 'metadatas'])
# Out:
# {'ids': ['b6f6943a-6025-49ed-aae6-ca5f1f3dabb7',
#   '5f4b7001-f768-44de-bf62-7ed42e7df763',
#   '8586e19d-dbb5-48ca-8f99-f8786e231ea0',
#   '3e1e7c74-f29d-4955-8a47-2c933089e2ea',
#   '1e90e99a-75e6-44cf-b9ea-8bad0ae61664'],
#  'embeddings': array([[-0.00210453, -0.00214285,  0.0268    , ..., -0.01707893,
#          -0.00366616,  0.01357884],
#         [-0.00268021, -0.00010323,  0.02815653, ..., -0.01501936,
#           0.00590092, -0.01164922],
#         [ 0.00092799, -0.00476   ,  0.0124662 , ..., -0.01731381,
#           0.00075886,  0.00296567],
#         [-0.02714536,  0.00885395,  0.02699314, ..., -0.02592762,
#           0.00900617, -0.01999116],
#         [-0.01810451,  0.01281202,  0.0347942 , ..., -0.03034012,
#          -0.00595078,  0.00521716]], shape=(5, 1536)),
#  'documents': ['Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.',
#   "Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
#   'MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.',
#   'Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.',
#   'Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'],
#  'uris': None,
#  'included': ['embeddings', 'documents', 'metadatas'],
#  'data': None,
#  'metadatas': [{'team': 'Royal Challengers Bangalore'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'}]}

# %%
# search with similarity score
vector_store.similarity_search_with_score(
    query='Who among these are a wicketkeeper?',
    k=2
)
# Out:
# [(Document(metadata={'team': 'Chennai Super Kings'}, page_content='MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.'),
#   0.38676244020462036),
#  (Document(metadata={'team': 'Chennai Super Kings'}, page_content='Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'),
#   0.3869445025920868)]

# %%
# meta-data filtering
vector_store.similarity_search_with_score(
    query="",
    filter={"team": "Chennai Super Kings"}
)
# Out:
# [(Document(metadata={'team': 'Chennai Super Kings'}, page_content='MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.'),
#   0.6488258242607117),
#  (Document(metadata={'team': 'Chennai Super Kings'}, page_content='Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'),
#   0.6566494703292847)]

# %%
# update documents
updated_doc1 = Document(
    page_content="Virat Kohli, the former captain of Royal Challengers Bangalore (RCB), is renowned for his aggressive leadership and consistent batting performances. He holds the record for the most runs in IPL history, including multiple centuries in a single season. Despite RCB not winning an IPL title under his captaincy, Kohli's passion and fitness set a benchmark for the league. His ability to chase targets and anchor innings has made him one of the most dependable players in T20 cricket.",
    metadata={"team": "Royal Challengers Bangalore"}
)

vector_store.update_document(document_id='09a39dc6-3ba6-4ea7-927e-fdda591da5e4', document=updated_doc1)

# %%
# view documents
vector_store.get(include=['embeddings','documents', 'metadatas'])
# Out:
# {'ids': ['b6f6943a-6025-49ed-aae6-ca5f1f3dabb7',
#   '5f4b7001-f768-44de-bf62-7ed42e7df763',
#   '8586e19d-dbb5-48ca-8f99-f8786e231ea0',
#   '3e1e7c74-f29d-4955-8a47-2c933089e2ea',
#   '1e90e99a-75e6-44cf-b9ea-8bad0ae61664'],
#  'embeddings': array([[-0.00210453, -0.00214285,  0.0268    , ..., -0.01707893,
#          -0.00366616,  0.01357884],
#         [-0.00268021, -0.00010323,  0.02815653, ..., -0.01501936,
#           0.00590092, -0.01164922],
#         [ 0.00092799, -0.00476   ,  0.0124662 , ..., -0.01731381,
#           0.00075886,  0.00296567],
#         [-0.02714536,  0.00885395,  0.02699314, ..., -0.02592762,
#           0.00900617, -0.01999116],
#         [-0.01810451,  0.01281202,  0.0347942 , ..., -0.03034012,
#          -0.00595078,  0.00521716]], shape=(5, 1536)),
#  'documents': ['Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.',
#   "Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
#   'MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.',
#   'Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.',
#   'Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'],
#  'uris': None,
#  'included': ['embeddings', 'documents', 'metadatas'],
#  'data': None,
#  'metadatas': [{'team': 'Royal Challengers Bangalore'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'}]}

# %%
# delete document
vector_store.delete(ids=['09a39dc6-3ba6-4ea7-927e-fdda591da5e4'])

# %%
# view documents
vector_store.get(include=['embeddings','documents', 'metadatas'])
# Out:
# {'ids': ['b6f6943a-6025-49ed-aae6-ca5f1f3dabb7',
#   '5f4b7001-f768-44de-bf62-7ed42e7df763',
#   '8586e19d-dbb5-48ca-8f99-f8786e231ea0',
#   '3e1e7c74-f29d-4955-8a47-2c933089e2ea',
#   '1e90e99a-75e6-44cf-b9ea-8bad0ae61664'],
#  'embeddings': array([[-0.00210453, -0.00214285,  0.0268    , ..., -0.01707893,
#          -0.00366616,  0.01357884],
#         [-0.00268021, -0.00010323,  0.02815653, ..., -0.01501936,
#           0.00590092, -0.01164922],
#         [ 0.00092799, -0.00476   ,  0.0124662 , ..., -0.01731381,
#           0.00075886,  0.00296567],
#         [-0.02714536,  0.00885395,  0.02699314, ..., -0.02592762,
#           0.00900617, -0.01999116],
#         [-0.01810451,  0.01281202,  0.0347942 , ..., -0.03034012,
#          -0.00595078,  0.00521716]], shape=(5, 1536)),
#  'documents': ['Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.',
#   "Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
#   'MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.',
#   'Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.',
#   'Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'],
#  'uris': None,
#  'included': ['embeddings', 'documents', 'metadatas'],
#  'data': None,
#  'metadatas': [{'team': 'Royal Challengers Bangalore'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'}]}
